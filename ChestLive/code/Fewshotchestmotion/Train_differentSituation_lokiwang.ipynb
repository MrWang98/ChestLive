# %%
# !pip install keras==2.1.2
# Out:
# Collecting keras==2.1.2
#   Downloading https://files.pythonhosted.org/packages/68/89/58ee5f56a9c26957d97217db41780ebedca3154392cb903c3f8a08a52208/Keras-2.1.2-py2.py3-none-any.whl (304kB)
#      |████████████████████████████████| 307kB 8.1MB/s
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras==2.1.2) (3.13)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from keras==2.1.2) (1.4.1)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras==2.1.2) (1.19.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from keras==2.1.2) (1.15.0)
# ERROR: textgenrnn 1.4.1 has requirement keras>=2.1.5, but you'll have keras 2.1.2 which is incompatible.
# Installing collected packages: keras
#   Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# Successfully installed keras-2.1.2

# %%
## authorize access to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# navigate to project directory
# %cd '/content/drive/My Drive/Colab Notebooks/Proj'
# %cd '/content/drive/My Drive/Proj/'
# Out:
# /content/drive/My Drive/Colab Notebooks/Proj

# %%
import os
print(os.path.exists('./split/test/ZJ'))
# Out:
# False

# %%
"""
    解决：如果有100个类，如何划分，训练集、验证集和测试集。可以60个类训练、20个验证，最后20个测试。
"""
# import keras
# from keras_preprocessing import image
#import matplotlib.pyplot as plt
import numpy as np
import random
import tensorflow as tf
#import keras
#from keras import layers
# from keras_preprocessing import image
from tensorflow import keras
from tensorflow.keras import layers
#import tensorflow_datasets as tfds
import Func_ReadAllData
import ReadData
from tensorflow.keras.layers import Input, Conv1D, Activation, Dropout, MaxPooling1D, Conv2D, MaxPooling2D
import copy

import os
# import keras.backend.tensorflow_backend as KTF
# os.environ["CUDA_VISIBLE_DEVICES"]="0"
# config = tf.compat.v1.ConfigProto()
# config.gpu_options.per_process_gpu_memory_fraction = 0.8
# session = tf.compat.v1.Session(config=config)
# KTF.set_session(session)

# %%
"""
## Define the Hyperparameters
"""
learning_rate = 0.003 # 0.003
meta_step_size = 0.1 # 0.25

inner_batch_size = 25
eval_batch_size = 25

meta_iters = 2000  # 8000
eval_iters = 5
inner_iters = 4

eval_interval = 1
train_shots = 20  # 20 5
shots = 20  # 5

classes = 3  # 5

# %%
# import readData
# class Dataset:
#     # This class will facilitate the creation of a few-shot dataset
#     # from Collected data that can be sampled from quickly while also
#     # allowing to create new labels at the same time.
#     def __init__(self, training):
#         self.data = {}
#         data_train, labels_train = ReadData.loadData(startPath="split",training=training)
#         for data_tmp, label_tmp in zip(data_train, labels_train):
#             data_tmp = np.expand_dims(data_tmp, axis=2)
#             if label_tmp not in self.data:
#                 self.data[label_tmp] = []
#             self.data[label_tmp].append(data_tmp)
#             self.labels = list(self.data.keys())

            

#     def get_mini_dataset(
#         self, batch_size, repetitions, shots, num_classes, split=False, test=False
#     ):
#         testImage = {}
#         testLabels = {}
#         temp_labels = np.zeros(shape=(num_classes * shots))
#         temp_images = np.zeros(shape=(num_classes * shots, 2000, 39, 1))
#         if split:
#             keys = np.zeros(shape=(num_classes))
#             test_labels = np.zeros(shape=(num_classes))
#             test_images = np.zeros(shape=(num_classes, 2000, 39, 1))

#         # Get a random subset of labels from the entire label set.

#         label_subset =[]
#         label_subset = np.array(label_subset)
#         tmpLabels = copy.deepcopy(self.labels)
#         for i in range(num_classes):                                # num_classes 次不放回采样
#             tmp = random.choices(tmpLabels,k=1)
#             label_subset = np.concatenate((label_subset,tmp),axis=0)
#             tmpLabels.remove(tmp[0])
#         # label_subset = random.choices(self.labels, k=num_classes)  # k 次有放回采样
#         for class_idx, class_obj in enumerate(label_subset):
#             test = []
#             if class_obj not in testImage:
#               testImage[class_obj] = []
#               testLabels[class_obj] = []
#             # Use enumerated index value as a temporary label for mini-batch in
#             # few shot learning.
#             temp_labels[class_idx * shots : (class_idx + 1) * shots] = class_idx

#             # If creating a split dataset for testing, select an extra sample from each label to create the test dataset.
#             if split:
#                 test_labels[class_idx] = class_idx
#                 images_to_split = random.choices(
#                     self.data[label_subset[class_idx]], k=shots + 1   # 选出shot + 1个data
#                 )

#                 test_images[class_idx] = images_to_split[-1]
#                 temp_images[
#                     class_idx * shots : (class_idx + 1) * shots
#                 ] = images_to_split[:-1]
#             else:
#                 # For each index in the randomly selected label_subset, sample the
#                 # necessary number of images.
#                 temp_images[
#                     class_idx * shots : (class_idx + 1) * shots
#                 ] = random.choices(self.data[label_subset[class_idx]], k=shots)

#         dataset = tf.data.Dataset.from_tensor_slices(
#             (temp_images.astype(np.float32), temp_labels.astype(np.int32))
#         )
#         dataset = dataset.shuffle(100).batch(batch_size).repeat(repetitions)  #打乱，喂入batch size，迭代repetitions次
#         if split:
#             return dataset, test_images, test_labels
#         return dataset

# %%
# train_dataset = Dataset(training=True)
# test_dataset = Dataset(training=False)

# %%
"""
## Build the model
"""
# def conv_bn(x):
#     x = layers.Conv2D(filters=64, kernel_size=3, strides=2, padding="same")(x)
#     x = layers.BatchNormalization()(x)
#     return layers.ReLU()(x)
#
# inputs = layers.Input(shape=(2000, 39, 1))
# x = conv_bn(inputs)
# x = conv_bn(x)
# x = conv_bn(x)
# x = conv_bn(x)
# x = layers.Flatten()(x)
# outputs = layers.Dense(classes, activation="softmax")(x)
# model = keras.Model(inputs=inputs, outputs=outputs)
# Out:
# '\n## Build the model\n'

# %%
"""
## Change the model
"""
# X_input = Input(input_shape)
inputs = layers.Input(shape=(2000, 39, 1)) #, 1
X = Conv2D(filters=32, kernel_size=4, strides=1, name='conv0')(inputs) # 32
X = Activation('relu')(X)
# X = Dropout(0.3)(X)
X = MaxPooling2D(pool_size=2, strides=2, name='max_pool0')(X) #pool_size=2, strides=2 (4)

X = Conv2D(256, 4, strides=1, name='conv1')(X)  # filter setting. 64
X = Activation('relu')(X)
# X = Dropout(0.3)(X)
X = MaxPooling2D(pool_size=2, strides=2, name='max_pool01')(X)

X = Conv2D(128, 4, strides=1, name='conv11')(X)  # filter setting. #128
X = Activation('relu')(X)
# X = Dropout(0.3)(X)
X = MaxPooling2D(pool_size=2, strides=2, name='max_pool1')(X)

X = Conv2D(64, 4, strides=1, name='conv2', padding="same")(X)  # filter setting. # 256
X = Activation('relu')(X)
# X = Dropout(0.3)(X)

X = MaxPooling2D(pool_size=2, strides=2, name='max_pool')(X) #2
X = layers.Flatten()(X)
X = layers.Dense(classes, activation='softmax', name='fc')(X)
model = keras.Model(inputs=inputs, outputs=X, name='VoiceChestModel_Keras')

model.compile(metrics=['accuracy'])
optimizer = keras.optimizers.SGD(learning_rate=learning_rate)

# %%
# """
# ## Train the model
# """
# # allData, allLabels = Func_ReadAllData.loadAllData(finalPath,1,training)
# # allData = np.expand_dims(allData, axis=3)
# # tmpAllLabels = []
# # for label in allLabels:
# #   tmpAllLabels.append(ord(label)-65)

# # tmpAllLabels = np.array(tmpAllLabels)
# import os
# training = []
# testing = []
# labelAcc = {}
# labelSum = {}
# count = 0
# print("开始")
# # start_iter = 0
# start_iter = len(training)
# for meta_iter in range(1054,meta_iters):
  
#   frac_done = meta_iter / meta_iters
#   cur_meta_step_size = (1 - frac_done) * meta_step_size 

#   # Temporarily save the weights from the model.
#   old_vars = model.get_weights()
#   # Get a sample from the full dataset. Train the few-shot.
#   mini_dataset = train_dataset.get_mini_dataset(
#       inner_batch_size, inner_iters, train_shots, classes
#   )

#   for images, labels in mini_dataset: #？
#     with tf.GradientTape() as tape:
#       preds = model(images)
#       loss = keras.losses.sparse_categorical_crossentropy(labels, preds)
#     grads = tape.gradient(target=loss, sources=model.trainable_weights) 
#     optimizer.apply_gradients(zip(grads, model.trainable_weights))
#   new_vars = model.get_weights()
#   # Perform SGD for the meta step.  SGD：对每个样本进行更新
#   for var in range(len(new_vars)):
#     new_vars[var] = old_vars[var] + (
#         (new_vars[var] - old_vars[var]) * cur_meta_step_size)
  
#   # After the meta-learning step, reload the newly-trained weights into the model.
#   model.set_weights(new_vars)


#   # Evaluation loop
#   if meta_iter % eval_interval == 0:
#     accuracies = []
#     for dataset in (train_dataset, test_dataset):
#       count+=1
#       # Sample a mini dataset from the full dataset.
#       train_set, test_images, test_labels = dataset.get_mini_dataset(
#         eval_batch_size, eval_iters, shots, classes, split=True)
#       # print(len(train_set),len(test_images),len(test_labels))
#       old_vars = model.get_weights()
#       # Train on the samples and get the resulting accuracies.
#       for images, labels in train_set:
#         # print(len(images),len(labels))
#         with tf.GradientTape() as tape:
#           preds = model(images)
#           loss = keras.losses.sparse_categorical_crossentropy(labels, preds)
#         grads = tape.gradient(target=loss, sources=model.trainable_weights)
#         optimizer.apply_gradients(zip(grads, model.trainable_weights))
#       test_preds = model.predict(test_images)
#       test_preds = tf.argmax(test_preds).numpy()
#       # print("labels:{}, preds:{}".format(test_labels,test_preds))

#       # test_loss, test_acc= model.evaluate(allData,tmpAllLabels)
#       # print(test_loss,test_acc)
      
#       num_correct = (test_preds == test_labels).sum()
#       # Reset the weights after getting the evaluation accuracies.
#       model.set_weights(old_vars)
#       accuracies.append(num_correct / classes)
#     training.append(accuracies[0])
#     testing.append(accuracies[1])

#     if meta_iter % 10 == 0:
      
#       print(
#           "batch %d: train=%f test=%f" % (meta_iter, accuracies[0], accuracies[1])
#       )
#       np.save(os.path.join("checkpoint","traing1.npy"),training)
#       np.save(os.path.join("checkpoint","testing1.npy"),testing)

#     #保存模型
#     if meta_iter % 100 == 0:
#       ModelName = os.path.join("checkpoint","model1.h5")
#       model.save(ModelName)
    
#     if meta_iter % 1999 == 0:
#       ModelName = os.path.join("checkpoint","model1.h5")
#       model.save(ModelName)

# %%
# # First, some preprocessing to smooth the training and testing arrays for display.
# import matplotlib.pyplot as plt
# window_length = 200
# train_s = np.r_[
#     training[window_length - 1 : 0 : -1], training, training[-1:-window_length:-1]
# ]
# test_s = np.r_[
#     testing[window_length - 1 : 0 : -1], testing, testing[-1:-window_length:-1]
# ]
# w = np.hamming(window_length)
# train_y = np.convolve(w / w.sum(), train_s, mode="valid") # Numpy 中的卷积函数
# test_y = np.convolve(w / w.sum(), test_s, mode="valid")

# # Display the training accuracies.
# x = np.arange(0, len(train_y), 1)
# plt.plot(x, train_y, x, test_y)
# plt.legend(["train","test"])
# plt.grid()

# %%
import copy

class testDataset:
    # This class will facilitate the creation of a few-shot dataset
    # from Collected data that can be sampled from quickly while also
    # allowing to create new labels at the same time.
    def __init__(self, training):
        self.data = {}
        self.test_data = {}
        data_train, labels_train = ReadData.loadData(startPath="split",training=training)
        data_test, labels_test = ReadData.loadData(startPath=os.path.join("Set2"),training=training)
        for data_tmp, label_tmp in zip(data_train, labels_train):
            data_tmp = np.expand_dims(data_tmp, axis=2)
            if label_tmp not in self.data:
                self.data[label_tmp] = []
            self.data[label_tmp].append(data_tmp)
            self.labels = list(self.data.keys())
        
        for data_tmp, label_tmp in zip(data_test, labels_test):
            data_tmp = np.expand_dims(data_tmp, axis=2)
            if label_tmp not in self.test_data:
                self.test_data[label_tmp] = []
            self.test_data[label_tmp].append(data_tmp)
            self.test_labels = list(self.test_data.keys())

            

    def get_mini_dataset(
        self, batch_size, repetitions, shots, num_classes, name,situation, test_size=5, split=False, test=False
    ):
        testImage = {}
        testLabels = {}
        temp_labels = np.zeros(shape=(num_classes * shots))
        temp_images = np.zeros(shape=(num_classes * shots, 2000, 39, 1))
        if split:
            keys = [0 for i in range(num_classes)]
            test_labels = np.zeros(shape=(num_classes))
            test_images = np.zeros(shape=(num_classes, 2000, 39, 1))

        # Get a random subset of labels from the entire label set.
        # label_subset = random.choices(self.labels, k=num_classes)  # k 次有放回采样
        label_subset =[]
        label_subset = np.array(label_subset)
        tmpLabels = copy.deepcopy(self.labels)
        for i in range(num_classes):                                # num_classes 次不放回采样
            tmp = random.choices(tmpLabels,k=1)
            label_subset = np.concatenate((label_subset,tmp),axis=0)
            tmpLabels.remove(tmp[0])
        for class_idx, class_obj in enumerate(label_subset):
            if class_obj not in testImage:
              # testImage[class_obj] = []
              # testLabels[class_obj] = []
              testImage[class_obj] = np.zeros(shape=(test_size, 2000, 39, 1))
              testLabels[class_obj] = np.zeros(shape=(test_size))
            # Use enumerated index value as a temporary label for mini-batch in
            # few shot learning.
            temp_labels[class_idx * shots : (class_idx + 1) * shots] = class_idx

            # If creating a split dataset for testing, select an extra sample from each label to create the test dataset.
            if split:
                # test_labels[class_idx] = class_idx
                test_labels[class_idx] = class_idx
                # images_to_split = random.choices(
                #     self.data[label_subset[class_idx]], k=shots + 1   # 选出shot + 1个data
                # )
                images_to_split = self.data[label_subset[class_idx]][0:shots+1]
                
                if test:
                  keys[class_idx] = class_obj
                  print("keys:{}".format(keys))

                  if(label_subset[class_idx]==name):
                    print(label_subset[class_idx]+"_"+situation)
                    testImage[class_obj] = random.choices(self.test_data[label_subset[class_idx]+"_"+situation],k=test_size)
                    testLabels[class_obj][0:] = class_idx 
                  else:
                    testImage[class_obj] = random.choices(self.data[label_subset[class_idx]][shots+1:],k=test_size)
                    testLabels[class_obj][0:] = class_idx
                   
                  # testImage[class_obj] = random.choices(self.data[label_subset[class_idx]][shots+1:],k=test_size)
                  # testLabels[class_obj][0:] = class_idx 

                  

                test_images[class_idx] = images_to_split[-1]
                temp_images[
                    class_idx * shots : (class_idx + 1) * shots
                ] = images_to_split[:-1]
            else:
                # For each index in the randomly selected label_subset, sample the
                # necessary number of images.
                temp_images[
                    class_idx * shots : (class_idx + 1) * shots
                ] = random.choices(self.data[label_subset[class_idx]], k=shots)

        # print(keys)
        dataset = tf.data.Dataset.from_tensor_slices(
            (temp_images.astype(np.float32), temp_labels.astype(np.int32))
        )
        dataset = dataset.shuffle(100).batch(batch_size).repeat(repetitions)  #打乱，喂入batch size，迭代repetitions次
        if test:
          tmpImage = []
          tmpLabels = []
          # print(len(list(testLabels.values())[0]))
          l = len(list(testLabels.values())[0])
          # print(l)
          for i in range(l):
            for k in label_subset:
              # print("i:{},lemgth:{}".format(i,len(list(testImage[k]))))
              # print("length:{},idx:{}".format(len(list(testImage[k])),i))
              tmpImage.append(list(testImage[k])[i])
              tmpLabels.append(list(testLabels[k])[i])
          # print(len(tmpImage))
          tmpImage = np.array(tmpImage)
          tmpLabels = np.array(tmpLabels)
          testset = tf.data.Dataset.from_tensor_slices((tmpImage.astype(np.float32), tmpLabels.astype(np.float32)))
          testset = testset.batch(num_classes)
          keys = np.array(keys)
          return dataset, test_images, test_labels, keys, testset
        if split:
            return dataset, test_images, test_labels
        return dataset

# %%
testSet = testDataset(False)
# Out:
# personlist:['GuXiang', 'KuangPeng', 'QinDang', 'XueMeng', 'ZSF', 'ChenZhiPeng']
# GuXiang
# /content/drive/My Drive/Colab Notebooks/Proj/ReadData.py:11: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   nda = np.array(data).shape[0]
# KuangPeng
# QinDang
# XueMeng
# ZSF
# ChenZhiPeng
# /content/drive/My Drive/Colab Notebooks/Proj/ReadData.py:67: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   dataValue = np.array(dataValue)
# /content/drive/My Drive/Colab Notebooks/Proj/ReadData.py:68: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   labelsValue = np.array(labelsValue)
# personlist:['XueMeng_5cm_mate30', 'XueMeng_20cm_mate30', 'XueMeng_10cm_mate30', 'XueMeng_25cm_mate30', 'XueMeng_30cm_mate30', 'XueMeng_55db_MATE30', 'XueMeng_65db_mate30', 'XueMeng_50db_MATE30', 'XueMeng_卧坐_mate30', 'XueMeng_走路_Mate30', 'XueMeng_躺_Mate30', 'XueMeng_站立_Mate30']
# XueMeng_5cm_mate30
# XueMeng_20cm_mate30
# XueMeng_10cm_mate30
# XueMeng_25cm_mate30
# XueMeng_30cm_mate30
# XueMeng_55db_MATE30
# XueMeng_65db_mate30
# XueMeng_50db_MATE30
# XueMeng_卧坐_mate30
# XueMeng_走路_Mate30
# XueMeng_躺_Mate30
# XueMeng_站立_Mate30

# %%
# trainSet = testDataset(True)

# %%
model = tf.keras.models.load_model("checkpoint/model1.h5")

# %%
dir_list = os.listdir(r"Set2/test/")
files=[]
for dir in dir_list:
    t=dir.split("_")
    if(len(t)>2):
        t1=t[0]
        t2='_'.join(t[1:])
    else:
        t1=t[0]
        t2=t[1]
    files.append([t1,t2])

# %%
for file in files:
  number = 200
  acc = {}
  shots=20
  all_count = {}  #保存各个类被抽取出的总次数
  label_dic = {}  #保存各个类被抽取出来后预测正确的次数，与上面的总次数相除暂定为预测的准确度
  for i in range(number):
    testing = []
    train_set, test_images, test_labels, keys, test_set = testSet.get_mini_dataset(
          eval_batch_size, eval_iters, shots, classes, name=file[0], situation=file[1], test_size=5, split=True, test=True
      )
    # print(test_set)
    for l in keys:
      if l not in label_dic:
        label_dic[l]=0
      if l not in all_count:
        all_count[l]=0
    old_vars1 = model.get_weights()
    # train
    for images, labels in train_set:
      # print(labels)
      with tf.GradientTape() as tape:
          preds = model(images)
          loss = keras.losses.sparse_categorical_crossentropy(labels, preds)
      # print(loss)
      # print("labels:{}, preds:{}".format(labels,preds))
      grads = tape.gradient(loss, model.trainable_weights)
      optimizer.apply_gradients(zip(grads, model.trainable_weights))
    test_preds = model.predict(test_images)
    test_preds = tf.argmax(test_preds).numpy()
    # if(i%50==0):
    #   print(i)
    print(i)
    # print("labels:{}, preds:{}".format(test_labels,test_preds))
    # test
    for images, labels in test_set:
        old_vars2 = model.get_weights()
        for label in labels:
          # print(label.numpy())
          all_count[keys[label.numpy().astype(int)]]+=1 
        preds = model.predict(images)
        preds = tf.argmax(preds).numpy()
        print("labels:{}, preds:{}".format(labels,preds))
        flags = (labels==preds)
        num_correct = flags.numpy().sum()
        testing.append(num_correct/classes)
        for idx, flag in enumerate(flags):
          if flag:
            label_dic[keys[idx]]+=1
        model.set_weights(old_vars2)
    model.set_weights(old_vars1)
  result = {}
  for key in label_dic.keys():
    result[key] = (label_dic[key]/all_count[key])*100
    print("label:{},  抽取出来的总次数:{},  其中预测正确的次数:{},  acc:{:.2f}%".format(key,all_count[key],label_dic[key],(label_dic[key]/all_count[key])*100))
  with open("Set2/result_{}.txt".format(file[0]),"a") as f:
    f.write("{}:{}\n".format(file[1],result[file[0]]))
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'XueMeng', 0]
# XueMeng_走路_Mate30
# keys:['ChenZhiPeng', 'XueMeng', 'GuXiang']
# 75
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'QinDang', 0]
# keys:['ChenZhiPeng', 'QinDang', 'GuXiang']
# 76
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'KuangPeng', 0]
# keys:['QinDang', 'KuangPeng', 'ZSF']
# 77
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'XueMeng', 0]
# XueMeng_走路_Mate30
# keys:['ChenZhiPeng', 'XueMeng', 'KuangPeng']
# 78
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ChenZhiPeng', 0]
# keys:['GuXiang', 'ChenZhiPeng', 'KuangPeng']
# 79
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_走路_Mate30
# keys:['XueMeng', 'ChenZhiPeng', 0]
# keys:['XueMeng', 'ChenZhiPeng', 'QinDang']
# 80
# labels:[0. 1. 2.], preds:[2 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 1 0]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'ChenZhiPeng', 0]
# keys:['ZSF', 'ChenZhiPeng', 'KuangPeng']
# 81
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'KuangPeng', 0]
# keys:['ChenZhiPeng', 'KuangPeng', 'GuXiang']
# 82
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_走路_Mate30
# keys:['XueMeng', 'KuangPeng', 0]
# keys:['XueMeng', 'KuangPeng', 'ChenZhiPeng']
# 83
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'XueMeng', 0]
# XueMeng_走路_Mate30
# keys:['GuXiang', 'XueMeng', 'ZSF']
# 84
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ZSF', 0]
# keys:['GuXiang', 'ZSF', 'QinDang']
# 85
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 0 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_走路_Mate30
# keys:['XueMeng', 'GuXiang', 0]
# keys:['XueMeng', 'GuXiang', 'QinDang']
# 86
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 1 0]
# labels:[0. 1. 2.], preds:[2 1 0]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'ChenZhiPeng', 0]
# keys:['KuangPeng', 'ChenZhiPeng', 'GuXiang']
# 87
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'QinDang', 0]
# keys:['ChenZhiPeng', 'QinDang', 'XueMeng']
# XueMeng_走路_Mate30
# 88
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 0]
# labels:[0. 1. 2.], preds:[0 2 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'QinDang', 0]
# keys:['ZSF', 'QinDang', 'GuXiang']
# 89
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'KuangPeng', 0]
# keys:['ChenZhiPeng', 'KuangPeng', 'QinDang']
# 90
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'XueMeng', 0]
# XueMeng_走路_Mate30
# keys:['GuXiang', 'XueMeng', 'QinDang']
# 91
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 0 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'KuangPeng', 0]
# keys:['GuXiang', 'KuangPeng', 'QinDang']
# 92
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'ZSF', 0]
# keys:['ChenZhiPeng', 'ZSF', 'GuXiang']
# 93
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'KuangPeng', 0]
# keys:['ZSF', 'KuangPeng', 'XueMeng']
# XueMeng_走路_Mate30
# 94
# labels:[0. 1. 2.], preds:[0 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'XueMeng', 0]
# XueMeng_走路_Mate30
# keys:['ChenZhiPeng', 'XueMeng', 'QinDang']
# 95
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 1]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ZSF', 0]
# keys:['GuXiang', 'ZSF', 'QinDang']
# 96
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'XueMeng', 0]
# XueMeng_走路_Mate30
# keys:['ChenZhiPeng', 'XueMeng', 'KuangPeng']
# 97
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 1]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'QinDang', 0]
# keys:['GuXiang', 'QinDang', 'XueMeng']
# XueMeng_走路_Mate30
# 98
# labels:[0. 1. 2.], preds:[0 2 1]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 1]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_走路_Mate30
# keys:['XueMeng', 'QinDang', 0]
# keys:['XueMeng', 'QinDang', 'KuangPeng']
# 99
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 0 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'XueMeng', 0]
# XueMeng_走路_Mate30
# keys:['ZSF', 'XueMeng', 'ChenZhiPeng']
# 100
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'XueMeng', 0]
# XueMeng_走路_Mate30
# keys:['ZSF', 'XueMeng', 'QinDang']
# 101
# labels:[0. 1. 2.], preds:[0 0 1]
# labels:[0. 1. 2.], preds:[0 0 2]
# labels:[0. 1. 2.], preds:[0 0 2]
# labels:[0. 1. 2.], preds:[0 0 2]
# labels:[0. 1. 2.], preds:[0 0 1]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'QinDang', 0]
# keys:['ChenZhiPeng', 'QinDang', 'GuXiang']
# 102
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_走路_Mate30
# keys:['XueMeng', 'ChenZhiPeng', 0]
# keys:['XueMeng', 'ChenZhiPeng', 'ZSF']
# 103
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'QinDang', 0]
# keys:['GuXiang', 'QinDang', 'ChenZhiPeng']
# 104
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ChenZhiPeng', 0]
# keys:['QinDang', 'ChenZhiPeng', 'KuangPeng']
# 105
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_走路_Mate30
# keys:['XueMeng', 'QinDang', 0]
# keys:['XueMeng', 'QinDang', 'ChenZhiPeng']
# 106
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 1 2]
# labels:[0. 1. 2.], preds:[1 0 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'KuangPeng', 0]
# keys:['ChenZhiPeng', 'KuangPeng', 'GuXiang']
# 107
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'QinDang', 0]
# keys:['GuXiang', 'QinDang', 'ZSF']
# 108
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'GuXiang', 0]
# keys:['ChenZhiPeng', 'GuXiang', 'KuangPeng']
# 109
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'QinDang', 0]
# keys:['KuangPeng', 'QinDang', 'ZSF']
# 110
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'ZSF', 0]
# keys:['KuangPeng', 'ZSF', 'XueMeng']
# XueMeng_走路_Mate30
# 111
# labels:[0. 1. 2.], preds:[2 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 1]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'QinDang', 0]
# keys:['KuangPeng', 'QinDang', 'ZSF']
# 112
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'QinDang', 0]
# keys:['ZSF', 'QinDang', 'KuangPeng']
# 113
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'KuangPeng', 0]
# keys:['GuXiang', 'KuangPeng', 'XueMeng']
# XueMeng_走路_Mate30
# 114
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'GuXiang', 0]
# keys:['ZSF', 'GuXiang', 'XueMeng']
# XueMeng_走路_Mate30
# 115
# labels:[0. 1. 2.], preds:[0 2 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 0 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'XueMeng', 0]
# XueMeng_走路_Mate30
# keys:['ZSF', 'XueMeng', 'ChenZhiPeng']
# 116
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_走路_Mate30
# keys:['XueMeng', 'QinDang', 0]
# keys:['XueMeng', 'QinDang', 'ChenZhiPeng']
# 117
# labels:[0. 1. 2.], preds:[2 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 0 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 0 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'GuXiang', 0]
# keys:['ZSF', 'GuXiang', 'ChenZhiPeng']
# 118
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'XueMeng', 0]
# XueMeng_走路_Mate30
# keys:['QinDang', 'XueMeng', 'KuangPeng']
# 119
# labels:[0. 1. 2.], preds:[0 2 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 1]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'XueMeng', 0]
# XueMeng_走路_Mate30
# keys:['ZSF', 'XueMeng', 'ChenZhiPeng']
# 120
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'GuXiang', 0]
# keys:['KuangPeng', 'GuXiang', 'XueMeng']
# XueMeng_走路_Mate30
# 121
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 1 0]
# labels:[0. 1. 2.], preds:[2 1 0]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'KuangPeng', 0]
# keys:['ZSF', 'KuangPeng', 'ChenZhiPeng']
# 122
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'XueMeng', 0]
# XueMeng_走路_Mate30
# keys:['ZSF', 'XueMeng', 'ChenZhiPeng']
# 123
# labels:[0. 1. 2.], preds:[0 0 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'GuXiang', 0]
# keys:['KuangPeng', 'GuXiang', 'XueMeng']
# XueMeng_走路_Mate30
# 124
# labels:[0. 1. 2.], preds:[2 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'KuangPeng', 0]
# keys:['ZSF', 'KuangPeng', 'QinDang']
# 125
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'XueMeng', 0]
# XueMeng_走路_Mate30
# keys:['ChenZhiPeng', 'XueMeng', 'ZSF']
# 126
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 1 0]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'KuangPeng', 0]
# keys:['ZSF', 'KuangPeng', 'GuXiang']
# 127
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_走路_Mate30
# keys:['XueMeng', 'QinDang', 0]
# keys:['XueMeng', 'QinDang', 'KuangPeng']
# 128
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 0 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'QinDang', 0]
# keys:['GuXiang', 'QinDang', 'XueMeng']
# XueMeng_走路_Mate30
# 129
# labels:[0. 1. 2.], preds:[0 2 1]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'XueMeng', 0]
# XueMeng_走路_Mate30
# keys:['ChenZhiPeng', 'XueMeng', 'GuXiang']
# 130
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'ChenZhiPeng', 0]
# keys:['ZSF', 'ChenZhiPeng', 'KuangPeng']
# 131
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_走路_Mate30
# keys:['XueMeng', 'QinDang', 0]
# keys:['XueMeng', 'QinDang', 'ZSF']
# 132
# labels:[0. 1. 2.], preds:[1 0 2]
# labels:[0. 1. 2.], preds:[2 0 2]
# labels:[0. 1. 2.], preds:[1 0 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ChenZhiPeng', 0]
# keys:['QinDang', 'ChenZhiPeng', 'GuXiang']
# 133
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'ZSF', 0]
# keys:['ChenZhiPeng', 'ZSF', 'QinDang']
# 134
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'ZSF', 0]
# keys:['ChenZhiPeng', 'ZSF', 'GuXiang']
# 135
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 1]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ZSF', 0]
# keys:['GuXiang', 'ZSF', 'ChenZhiPeng']
# 136
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'ChenZhiPeng', 0]
# keys:['KuangPeng', 'ChenZhiPeng', 'XueMeng']
# XueMeng_走路_Mate30
# 137
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_走路_Mate30
# keys:['XueMeng', 'KuangPeng', 0]
# keys:['XueMeng', 'KuangPeng', 'GuXiang']
# 138
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'QinDang', 0]
# keys:['ZSF', 'QinDang', 'GuXiang']
# 139
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'GuXiang', 0]
# keys:['QinDang', 'GuXiang', 'KuangPeng']
# 140
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'QinDang', 0]
# keys:['KuangPeng', 'QinDang', 'ChenZhiPeng']
# 141
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_走路_Mate30
# keys:['XueMeng', 'GuXiang', 0]
# keys:['XueMeng', 'GuXiang', 'ZSF']
# 142
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ChenZhiPeng', 0]
# keys:['GuXiang', 'ChenZhiPeng', 'QinDang']
# 143
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'GuXiang', 0]
# keys:['ChenZhiPeng', 'GuXiang', 'QinDang']
# 144
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'GuXiang', 0]
# keys:['ZSF', 'GuXiang', 'KuangPeng']
# 145
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ZSF', 0]
# keys:['GuXiang', 'ZSF', 'ChenZhiPeng']
# 146
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'GuXiang', 0]
# keys:['ChenZhiPeng', 'GuXiang', 'KuangPeng']
# 147
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'GuXiang', 0]
# keys:['ZSF', 'GuXiang', 'KuangPeng']
# 148
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 0 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'QinDang', 0]
# keys:['KuangPeng', 'QinDang', 'XueMeng']
# XueMeng_走路_Mate30
# 149
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'KuangPeng', 0]
# keys:['QinDang', 'KuangPeng', 'GuXiang']
# 150
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'ZSF', 0]
# keys:['KuangPeng', 'ZSF', 'ChenZhiPeng']
# 151
# labels:[0. 1. 2.], preds:[0 2 1]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'XueMeng', 0]
# XueMeng_走路_Mate30
# keys:['KuangPeng', 'XueMeng', 'ZSF']
# 152
# labels:[0. 1. 2.], preds:[0 2 2]
# labels:[0. 1. 2.], preds:[0 2 2]
# labels:[0. 1. 2.], preds:[0 2 2]
# labels:[0. 1. 2.], preds:[0 2 2]
# labels:[0. 1. 2.], preds:[0 2 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'QinDang', 0]
# keys:['ZSF', 'QinDang', 'GuXiang']
# 153
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'KuangPeng', 0]
# keys:['ChenZhiPeng', 'KuangPeng', 'XueMeng']
# XueMeng_走路_Mate30
# 154
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ZSF', 0]
# keys:['GuXiang', 'ZSF', 'ChenZhiPeng']
# 155
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 1]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ChenZhiPeng', 0]
# keys:['QinDang', 'ChenZhiPeng', 'KuangPeng']
# 156
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_走路_Mate30
# keys:['XueMeng', 'GuXiang', 0]
# keys:['XueMeng', 'GuXiang', 'KuangPeng']
# 157
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'QinDang', 0]
# keys:['ZSF', 'QinDang', 'ChenZhiPeng']
# 158
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'ZSF', 0]
# keys:['KuangPeng', 'ZSF', 'XueMeng']
# XueMeng_走路_Mate30
# 159
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 1]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 1 0]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'XueMeng', 0]
# XueMeng_走路_Mate30
# keys:['KuangPeng', 'XueMeng', 'QinDang']
# 160
# labels:[0. 1. 2.], preds:[0 2 1]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ZSF', 0]
# keys:['QinDang', 'ZSF', 'GuXiang']
# 161
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 0]
# labels:[0. 1. 2.], preds:[0 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'GuXiang', 0]
# keys:['QinDang', 'GuXiang', 'XueMeng']
# XueMeng_走路_Mate30
# 162
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 0]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'QinDang', 0]
# keys:['ZSF', 'QinDang', 'XueMeng']
# XueMeng_走路_Mate30
# 163
# labels:[0. 1. 2.], preds:[0 1 0]
# labels:[0. 1. 2.], preds:[0 1 0]
# labels:[0. 1. 2.], preds:[0 2 0]
# labels:[0. 1. 2.], preds:[0 1 0]
# labels:[0. 1. 2.], preds:[0 1 0]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'XueMeng', 0]
# XueMeng_走路_Mate30
# keys:['ZSF', 'XueMeng', 'ChenZhiPeng']
# 164
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'GuXiang', 0]
# keys:['QinDang', 'GuXiang', 'XueMeng']
# XueMeng_走路_Mate30
# 165
# labels:[0. 1. 2.], preds:[2 1 0]
# labels:[0. 1. 2.], preds:[0 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'ZSF', 0]
# keys:['ChenZhiPeng', 'ZSF', 'KuangPeng']
# 166
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'QinDang', 0]
# keys:['ZSF', 'QinDang', 'XueMeng']
# XueMeng_走路_Mate30
# 167
# labels:[0. 1. 2.], preds:[0 1 0]
# labels:[0. 1. 2.], preds:[0 2 0]
# labels:[0. 1. 2.], preds:[0 1 0]
# labels:[0. 1. 2.], preds:[0 1 0]
# labels:[0. 1. 2.], preds:[0 2 0]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'QinDang', 0]
# keys:['GuXiang', 'QinDang', 'ZSF']
# 168
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'GuXiang', 0]
# keys:['ZSF', 'GuXiang', 'KuangPeng']
# 169
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ChenZhiPeng', 0]
# keys:['GuXiang', 'ChenZhiPeng', 'KuangPeng']
# 170
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'XueMeng', 0]
# XueMeng_走路_Mate30
# keys:['QinDang', 'XueMeng', 'KuangPeng']
# 171
# labels:[0. 1. 2.], preds:[0 0 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'KuangPeng', 0]
# keys:['ChenZhiPeng', 'KuangPeng', 'ZSF']
# 172
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_走路_Mate30
# keys:['XueMeng', 'ZSF', 0]
# keys:['XueMeng', 'ZSF', 'GuXiang']
# 173
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'QinDang', 0]
# keys:['ChenZhiPeng', 'QinDang', 'KuangPeng']
# 174
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'KuangPeng', 0]
# keys:['QinDang', 'KuangPeng', 'ZSF']
# 175
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 0 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 1]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'ZSF', 0]
# keys:['KuangPeng', 'ZSF', 'XueMeng']
# XueMeng_走路_Mate30
# 176
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'XueMeng', 0]
# XueMeng_走路_Mate30
# keys:['ZSF', 'XueMeng', 'ChenZhiPeng']
# 177
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 0 2]
# labels:[0. 1. 2.], preds:[1 0 2]
# labels:[0. 1. 2.], preds:[1 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'GuXiang', 0]
# keys:['ChenZhiPeng', 'GuXiang', 'KuangPeng']
# 178
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'GuXiang', 0]
# keys:['QinDang', 'GuXiang', 'KuangPeng']
# 179
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'XueMeng', 0]
# XueMeng_走路_Mate30
# keys:['KuangPeng', 'XueMeng', 'QinDang']
# 180
# labels:[0. 1. 2.], preds:[0 0 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'XueMeng', 0]
# XueMeng_走路_Mate30
# keys:['KuangPeng', 'XueMeng', 'ChenZhiPeng']
# 181
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'QinDang', 0]
# keys:['ChenZhiPeng', 'QinDang', 'GuXiang']
# 182
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'GuXiang', 0]
# keys:['QinDang', 'GuXiang', 'XueMeng']
# XueMeng_走路_Mate30
# 183
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 1 0]
# keys:['XueMeng', 0, 0]
# XueMeng_走路_Mate30
# keys:['XueMeng', 'QinDang', 0]
# keys:['XueMeng', 'QinDang', 'ZSF']
# 184
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 1 2]
# labels:[0. 1. 2.], preds:[1 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'GuXiang', 0]
# keys:['QinDang', 'GuXiang', 'ChenZhiPeng']
# 185
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'XueMeng', 0]
# XueMeng_走路_Mate30
# keys:['KuangPeng', 'XueMeng', 'ZSF']
# 186
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'XueMeng', 0]
# XueMeng_走路_Mate30
# keys:['GuXiang', 'XueMeng', 'QinDang']
# 187
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ZSF', 0]
# keys:['QinDang', 'ZSF', 'KuangPeng']
# 188
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'GuXiang', 0]
# keys:['QinDang', 'GuXiang', 'KuangPeng']
# 189
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'ChenZhiPeng', 0]
# keys:['KuangPeng', 'ChenZhiPeng', 'ZSF']
# 190
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 0 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'ZSF', 0]
# keys:['ChenZhiPeng', 'ZSF', 'XueMeng']
# XueMeng_走路_Mate30
# 191
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'KuangPeng', 0]
# keys:['QinDang', 'KuangPeng', 'ChenZhiPeng']
# 192
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'QinDang', 0]
# keys:['ChenZhiPeng', 'QinDang', 'ZSF']
# 193
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_走路_Mate30
# keys:['XueMeng', 'ChenZhiPeng', 0]
# keys:['XueMeng', 'ChenZhiPeng', 'ZSF']
# 194
# labels:[0. 1. 2.], preds:[1 1 2]
# labels:[0. 1. 2.], preds:[1 0 2]
# labels:[0. 1. 2.], preds:[0 0 2]
# labels:[0. 1. 2.], preds:[0 0 2]
# labels:[0. 1. 2.], preds:[1 0 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'QinDang', 0]
# keys:['GuXiang', 'QinDang', 'KuangPeng']
# 195
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'ZSF', 0]
# keys:['ChenZhiPeng', 'ZSF', 'QinDang']
# 196
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'GuXiang', 0]
# keys:['QinDang', 'GuXiang', 'ChenZhiPeng']
# 197
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'ChenZhiPeng', 0]
# keys:['KuangPeng', 'ChenZhiPeng', 'QinDang']
# 198
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'XueMeng', 0]
# XueMeng_走路_Mate30
# keys:['ZSF', 'XueMeng', 'QinDang']
# 199
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 1]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# label:ZSF,  抽取出来的总次数:470,  其中预测正确的次数:454,  acc:96.60%
# label:ChenZhiPeng,  抽取出来的总次数:495,  其中预测正确的次数:486,  acc:98.18%
# label:QinDang,  抽取出来的总次数:560,  其中预测正确的次数:508,  acc:90.71%
# label:GuXiang,  抽取出来的总次数:500,  其中预测正确的次数:484,  acc:96.80%
# label:KuangPeng,  抽取出来的总次数:510,  其中预测正确的次数:490,  acc:96.08%
# label:XueMeng,  抽取出来的总次数:465,  其中预测正确的次数:340,  acc:73.12%
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ZSF', 0]
# keys:['QinDang', 'ZSF', 'GuXiang']
# 0
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'XueMeng', 0]
# XueMeng_躺_Mate30
# keys:['GuXiang', 'XueMeng', 'ChenZhiPeng']
# 1
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'GuXiang', 0]
# keys:['KuangPeng', 'GuXiang', 'ChenZhiPeng']
# 2
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ZSF', 0]
# keys:['GuXiang', 'ZSF', 'ChenZhiPeng']
# 3
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'KuangPeng', 0]
# keys:['QinDang', 'KuangPeng', 'XueMeng']
# XueMeng_躺_Mate30
# 4
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'ZSF', 0]
# keys:['KuangPeng', 'ZSF', 'XueMeng']
# XueMeng_躺_Mate30
# 5
# labels:[0. 1. 2.], preds:[2 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'XueMeng', 0]
# XueMeng_躺_Mate30
# keys:['QinDang', 'XueMeng', 'KuangPeng']
# 6
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'ZSF', 0]
# keys:['KuangPeng', 'ZSF', 'GuXiang']
# 7
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'KuangPeng', 0]
# keys:['QinDang', 'KuangPeng', 'GuXiang']
# 8
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_躺_Mate30
# keys:['XueMeng', 'QinDang', 0]
# keys:['XueMeng', 'QinDang', 'ChenZhiPeng']
# 9
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 1 2]
# labels:[0. 1. 2.], preds:[1 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'QinDang', 0]
# keys:['ZSF', 'QinDang', 'KuangPeng']
# 10
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'QinDang', 0]
# keys:['ZSF', 'QinDang', 'KuangPeng']
# 11
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ChenZhiPeng', 0]
# keys:['QinDang', 'ChenZhiPeng', 'GuXiang']
# 12
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'XueMeng', 0]
# XueMeng_躺_Mate30
# keys:['ZSF', 'XueMeng', 'ChenZhiPeng']
# 13
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ChenZhiPeng', 0]
# keys:['QinDang', 'ChenZhiPeng', 'KuangPeng']
# 14
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'KuangPeng', 0]
# keys:['ZSF', 'KuangPeng', 'GuXiang']
# 15
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'KuangPeng', 0]
# keys:['ChenZhiPeng', 'KuangPeng', 'ZSF']
# 16
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'XueMeng', 0]
# XueMeng_躺_Mate30
# keys:['QinDang', 'XueMeng', 'ZSF']
# 17
# labels:[0. 1. 2.], preds:[1 0 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'GuXiang', 0]
# keys:['ChenZhiPeng', 'GuXiang', 'QinDang']
# 18
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'KuangPeng', 0]
# keys:['GuXiang', 'KuangPeng', 'XueMeng']
# XueMeng_躺_Mate30
# 19
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'ChenZhiPeng', 0]
# keys:['ZSF', 'ChenZhiPeng', 'XueMeng']
# XueMeng_躺_Mate30
# 20
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'GuXiang', 0]
# keys:['QinDang', 'GuXiang', 'ZSF']
# 21
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'ChenZhiPeng', 0]
# keys:['ZSF', 'ChenZhiPeng', 'GuXiang']
# 22
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 0 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 0]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'ChenZhiPeng', 0]
# keys:['KuangPeng', 'ChenZhiPeng', 'XueMeng']
# XueMeng_躺_Mate30
# 23
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'XueMeng', 0]
# XueMeng_躺_Mate30
# keys:['ChenZhiPeng', 'XueMeng', 'KuangPeng']
# 24
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'ChenZhiPeng', 0]
# keys:['KuangPeng', 'ChenZhiPeng', 'GuXiang']
# 25
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'XueMeng', 0]
# XueMeng_躺_Mate30
# keys:['QinDang', 'XueMeng', 'GuXiang']
# 26
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 0 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'QinDang', 0]
# keys:['KuangPeng', 'QinDang', 'ZSF']
# 27
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'KuangPeng', 0]
# keys:['ChenZhiPeng', 'KuangPeng', 'QinDang']
# 28
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'QinDang', 0]
# keys:['ZSF', 'QinDang', 'GuXiang']
# 29
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 1]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ZSF', 0]
# keys:['QinDang', 'ZSF', 'KuangPeng']
# 30
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'QinDang', 0]
# keys:['ChenZhiPeng', 'QinDang', 'XueMeng']
# XueMeng_躺_Mate30
# 31
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'QinDang', 0]
# keys:['ChenZhiPeng', 'QinDang', 'GuXiang']
# 32
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'XueMeng', 0]
# XueMeng_躺_Mate30
# keys:['ChenZhiPeng', 'XueMeng', 'ZSF']
# 33
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'GuXiang', 0]
# keys:['KuangPeng', 'GuXiang', 'XueMeng']
# XueMeng_躺_Mate30
# 34
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ChenZhiPeng', 0]
# keys:['GuXiang', 'ChenZhiPeng', 'QinDang']
# 35
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_躺_Mate30
# keys:['XueMeng', 'ChenZhiPeng', 0]
# keys:['XueMeng', 'ChenZhiPeng', 'QinDang']
# 36
# labels:[0. 1. 2.], preds:[2 1 0]
# labels:[0. 1. 2.], preds:[2 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'QinDang', 0]
# keys:['GuXiang', 'QinDang', 'XueMeng']
# XueMeng_躺_Mate30
# 37
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 0 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'ChenZhiPeng', 0]
# keys:['KuangPeng', 'ChenZhiPeng', 'ZSF']
# 38
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_躺_Mate30
# keys:['XueMeng', 'ChenZhiPeng', 0]
# keys:['XueMeng', 'ChenZhiPeng', 'GuXiang']
# 39
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ChenZhiPeng', 0]
# keys:['GuXiang', 'ChenZhiPeng', 'ZSF']
# 40
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 0 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'KuangPeng', 0]
# keys:['GuXiang', 'KuangPeng', 'QinDang']
# 41
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 1]
# keys:['XueMeng', 0, 0]
# XueMeng_躺_Mate30
# keys:['XueMeng', 'ZSF', 0]
# keys:['XueMeng', 'ZSF', 'QinDang']
# 42
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'XueMeng', 0]
# XueMeng_躺_Mate30
# keys:['ChenZhiPeng', 'XueMeng', 'ZSF']
# 43
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_躺_Mate30
# keys:['XueMeng', 'ZSF', 0]
# keys:['XueMeng', 'ZSF', 'QinDang']
# 44
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'XueMeng', 0]
# XueMeng_躺_Mate30
# keys:['QinDang', 'XueMeng', 'ZSF']
# 45
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 0 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'KuangPeng', 0]
# keys:['ChenZhiPeng', 'KuangPeng', 'ZSF']
# 46
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ZSF', 0]
# keys:['GuXiang', 'ZSF', 'KuangPeng']
# 47
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ChenZhiPeng', 0]
# keys:['QinDang', 'ChenZhiPeng', 'GuXiang']
# 48
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 0]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'ZSF', 0]
# keys:['ChenZhiPeng', 'ZSF', 'KuangPeng']
# 49
# labels:[0. 1. 2.], preds:[0 1 2]
# ...
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'QinDang', 0]
# keys:['ZSF', 'QinDang', 'XueMeng']
# XueMeng_站立_Mate30
# 143
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'QinDang', 0]
# keys:['ChenZhiPeng', 'QinDang', 'XueMeng']
# XueMeng_站立_Mate30
# 144
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 1]
# keys:['XueMeng', 0, 0]
# XueMeng_站立_Mate30
# keys:['XueMeng', 'ChenZhiPeng', 0]
# keys:['XueMeng', 'ChenZhiPeng', 'GuXiang']
# 145
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ZSF', 0]
# keys:['QinDang', 'ZSF', 'KuangPeng']
# 146
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ChenZhiPeng', 0]
# keys:['QinDang', 'ChenZhiPeng', 'XueMeng']
# XueMeng_站立_Mate30
# 147
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'QinDang', 0]
# keys:['ChenZhiPeng', 'QinDang', 'GuXiang']
# 148
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_站立_Mate30
# keys:['XueMeng', 'ChenZhiPeng', 0]
# keys:['XueMeng', 'ChenZhiPeng', 'QinDang']
# 149
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'KuangPeng', 0]
# keys:['ZSF', 'KuangPeng', 'GuXiang']
# 150
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'XueMeng', 0]
# XueMeng_站立_Mate30
# keys:['ZSF', 'XueMeng', 'GuXiang']
# 151
# labels:[0. 1. 2.], preds:[2 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'QinDang', 0]
# keys:['ZSF', 'QinDang', 'GuXiang']
# 152
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'KuangPeng', 0]
# keys:['ChenZhiPeng', 'KuangPeng', 'GuXiang']
# 153
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 1]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'XueMeng', 0]
# XueMeng_站立_Mate30
# keys:['KuangPeng', 'XueMeng', 'QinDang']
# 154
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'XueMeng', 0]
# XueMeng_站立_Mate30
# keys:['QinDang', 'XueMeng', 'ChenZhiPeng']
# 155
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ChenZhiPeng', 0]
# keys:['QinDang', 'ChenZhiPeng', 'ZSF']
# 156
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 1]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_站立_Mate30
# keys:['XueMeng', 'GuXiang', 0]
# keys:['XueMeng', 'GuXiang', 'KuangPeng']
# 157
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'ChenZhiPeng', 0]
# keys:['KuangPeng', 'ChenZhiPeng', 'ZSF']
# 158
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'XueMeng', 0]
# XueMeng_站立_Mate30
# keys:['ChenZhiPeng', 'XueMeng', 'GuXiang']
# 159
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 1]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'GuXiang', 0]
# keys:['QinDang', 'GuXiang', 'XueMeng']
# XueMeng_站立_Mate30
# 160
# labels:[0. 1. 2.], preds:[0 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ZSF', 0]
# keys:['GuXiang', 'ZSF', 'ChenZhiPeng']
# 161
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'KuangPeng', 0]
# keys:['QinDang', 'KuangPeng', 'GuXiang']
# 162
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'QinDang', 0]
# keys:['KuangPeng', 'QinDang', 'XueMeng']
# XueMeng_站立_Mate30
# 163
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'GuXiang', 0]
# keys:['KuangPeng', 'GuXiang', 'XueMeng']
# XueMeng_站立_Mate30
# 164
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_站立_Mate30
# keys:['XueMeng', 'ChenZhiPeng', 0]
# keys:['XueMeng', 'ChenZhiPeng', 'GuXiang']
# 165
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'ZSF', 0]
# keys:['ChenZhiPeng', 'ZSF', 'QinDang']
# 166
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'ZSF', 0]
# keys:['KuangPeng', 'ZSF', 'GuXiang']
# 167
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'XueMeng', 0]
# XueMeng_站立_Mate30
# keys:['GuXiang', 'XueMeng', 'ZSF']
# 168
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'XueMeng', 0]
# XueMeng_站立_Mate30
# keys:['QinDang', 'XueMeng', 'ZSF']
# 169
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ZSF', 0]
# keys:['GuXiang', 'ZSF', 'QinDang']
# 170
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'GuXiang', 0]
# keys:['ChenZhiPeng', 'GuXiang', 'QinDang']
# 171
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'KuangPeng', 0]
# keys:['GuXiang', 'KuangPeng', 'ChenZhiPeng']
# 172
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'XueMeng', 0]
# XueMeng_站立_Mate30
# keys:['GuXiang', 'XueMeng', 'ChenZhiPeng']
# 173
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'QinDang', 0]
# keys:['ChenZhiPeng', 'QinDang', 'XueMeng']
# XueMeng_站立_Mate30
# 174
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'KuangPeng', 0]
# keys:['GuXiang', 'KuangPeng', 'XueMeng']
# XueMeng_站立_Mate30
# 175
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'KuangPeng', 0]
# keys:['ChenZhiPeng', 'KuangPeng', 'ZSF']
# 176
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_站立_Mate30
# keys:['XueMeng', 'KuangPeng', 0]
# keys:['XueMeng', 'KuangPeng', 'ChenZhiPeng']
# 177
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'ChenZhiPeng', 0]
# keys:['ZSF', 'ChenZhiPeng', 'QinDang']
# 178
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_站立_Mate30
# keys:['XueMeng', 'ZSF', 0]
# keys:['XueMeng', 'ZSF', 'GuXiang']
# 179
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ChenZhiPeng', 0]
# keys:['QinDang', 'ChenZhiPeng', 'XueMeng']
# XueMeng_站立_Mate30
# 180
# labels:[0. 1. 2.], preds:[0 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_站立_Mate30
# keys:['XueMeng', 'KuangPeng', 0]
# keys:['XueMeng', 'KuangPeng', 'ZSF']
# 181
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_站立_Mate30
# keys:['XueMeng', 'KuangPeng', 0]
# keys:['XueMeng', 'KuangPeng', 'GuXiang']
# 182
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'GuXiang', 0]
# keys:['ZSF', 'GuXiang', 'ChenZhiPeng']
# 183
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'XueMeng', 0]
# XueMeng_站立_Mate30
# keys:['KuangPeng', 'XueMeng', 'ZSF']
# 184
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'GuXiang', 0]
# keys:['ChenZhiPeng', 'GuXiang', 'QinDang']
# 185
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'XueMeng', 0]
# XueMeng_站立_Mate30
# keys:['KuangPeng', 'XueMeng', 'GuXiang']
# 186
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'KuangPeng', 0]
# keys:['QinDang', 'KuangPeng', 'ChenZhiPeng']
# 187
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ZSF', 0]
# keys:['GuXiang', 'ZSF', 'QinDang']
# 188
# labels:[0. 1. 2.], preds:[2 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ZSF', 0]
# keys:['QinDang', 'ZSF', 'ChenZhiPeng']
# 189
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'QinDang', 0]
# keys:['ChenZhiPeng', 'QinDang', 'GuXiang']
# 190
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['KuangPeng', 0, 0]
# keys:['KuangPeng', 'GuXiang', 0]
# keys:['KuangPeng', 'GuXiang', 'QinDang']
# 191
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'XueMeng', 0]
# XueMeng_站立_Mate30
# keys:['QinDang', 'XueMeng', 'ChenZhiPeng']
# 192
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenZhiPeng', 0, 0]
# keys:['ChenZhiPeng', 'ZSF', 0]
# keys:['ChenZhiPeng', 'ZSF', 'GuXiang']
# 193
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ZSF', 0]
# keys:['GuXiang', 'ZSF', 'KuangPeng']
# 194
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'GuXiang', 0]
# keys:['QinDang', 'GuXiang', 'KuangPeng']
# 195
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_站立_Mate30
# keys:['XueMeng', 'QinDang', 0]
# keys:['XueMeng', 'QinDang', 'GuXiang']
# 196
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'KuangPeng', 0]
# keys:['QinDang', 'KuangPeng', 'ZSF']
# 197
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 1]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_站立_Mate30
# keys:['XueMeng', 'ZSF', 0]
# keys:['XueMeng', 'ZSF', 'KuangPeng']
# 198
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# XueMeng_站立_Mate30
# keys:['XueMeng', 'QinDang', 0]
# keys:['XueMeng', 'QinDang', 'KuangPeng']
# 199
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# label:XueMeng,  抽取出来的总次数:510,  其中预测正确的次数:480,  acc:94.12%
# label:ChenZhiPeng,  抽取出来的总次数:425,  其中预测正确的次数:412,  acc:96.94%
# label:GuXiang,  抽取出来的总次数:575,  其中预测正确的次数:549,  acc:95.48%
# label:ZSF,  抽取出来的总次数:475,  其中预测正确的次数:458,  acc:96.42%
# label:QinDang,  抽取出来的总次数:500,  其中预测正确的次数:492,  acc:98.40%
# label:KuangPeng,  抽取出来的总次数:515,  其中预测正确的次数:504,  acc:97.86%

# %%
import os
dir = './Set2/test/LiuSiYing_5cm_魅族16th'
print(os.path.exists(dir))

# %%
import os
import time
dir = './split/test/KuangPeng'
flag = os.path.exists(dir)
print("开始")
while flag!=True:
  print("一次尝试")
  flag = os.path.exists(dir)
  time.sleep(2)
print("已修改")
# Out:
# 开始
# 已修改
