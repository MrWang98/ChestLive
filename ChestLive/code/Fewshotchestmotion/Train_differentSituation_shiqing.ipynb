# %%
# !pip install keras==2.1.2
# Out:
# Collecting keras==2.1.2
#   Downloading https://files.pythonhosted.org/packages/68/89/58ee5f56a9c26957d97217db41780ebedca3154392cb903c3f8a08a52208/Keras-2.1.2-py2.py3-none-any.whl (304kB)
#      |████████████████████████████████| 307kB 8.1MB/s
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras==2.1.2) (3.13)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from keras==2.1.2) (1.4.1)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras==2.1.2) (1.19.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from keras==2.1.2) (1.15.0)
# ERROR: textgenrnn 1.4.1 has requirement keras>=2.1.5, but you'll have keras 2.1.2 which is incompatible.
# Installing collected packages: keras
#   Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# Successfully installed keras-2.1.2

# %%
## authorize access to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# navigate to project directory
# %cd '/content/drive/My Drive/Colab Notebooks/Proj'
# %cd '/content/drive/My Drive/Proj/'
# Out:
# /content/drive/.shortcut-targets-by-id/1dru5PCdCB6aT1Kb-75g8GYG37BEdecQR/Proj

# %%
import os
print(os.path.exists('./split/test/ZJ'))
# Out:
# False

# %%
"""
    解决：如果有100个类，如何划分，训练集、验证集和测试集。可以60个类训练、20个验证，最后20个测试。
"""
# import keras
# from keras_preprocessing import image
#import matplotlib.pyplot as plt
import numpy as np
import random
import tensorflow as tf
#import keras
#from keras import layers
# from keras_preprocessing import image
from tensorflow import keras
from tensorflow.keras import layers
#import tensorflow_datasets as tfds
import Func_ReadAllData
import ReadData
from tensorflow.keras.layers import Input, Conv1D, Activation, Dropout, MaxPooling1D, Conv2D, MaxPooling2D
import copy

import os
# import keras.backend.tensorflow_backend as KTF
# os.environ["CUDA_VISIBLE_DEVICES"]="0"
# config = tf.compat.v1.ConfigProto()
# config.gpu_options.per_process_gpu_memory_fraction = 0.8
# session = tf.compat.v1.Session(config=config)
# KTF.set_session(session)

# %%
"""
## Define the Hyperparameters
"""
learning_rate = 0.003 # 0.003
meta_step_size = 0.1 # 0.25

inner_batch_size = 25
eval_batch_size = 25

meta_iters = 2000  # 8000
eval_iters = 5
inner_iters = 4

eval_interval = 1
train_shots = 20  # 20 5
shots = 20  # 5

classes = 3  # 5

# %%
# import readData
# class Dataset:
#     # This class will facilitate the creation of a few-shot dataset
#     # from Collected data that can be sampled from quickly while also
#     # allowing to create new labels at the same time.
#     def __init__(self, training):
#         self.data = {}
#         data_train, labels_train = ReadData.loadData(startPath="split",training=training)
#         for data_tmp, label_tmp in zip(data_train, labels_train):
#             data_tmp = np.expand_dims(data_tmp, axis=2)
#             if label_tmp not in self.data:
#                 self.data[label_tmp] = []
#             self.data[label_tmp].append(data_tmp)
#             self.labels = list(self.data.keys())

            

#     def get_mini_dataset(
#         self, batch_size, repetitions, shots, num_classes, split=False, test=False
#     ):
#         testImage = {}
#         testLabels = {}
#         temp_labels = np.zeros(shape=(num_classes * shots))
#         temp_images = np.zeros(shape=(num_classes * shots, 2000, 39, 1))
#         if split:
#             keys = np.zeros(shape=(num_classes))
#             test_labels = np.zeros(shape=(num_classes))
#             test_images = np.zeros(shape=(num_classes, 2000, 39, 1))

#         # Get a random subset of labels from the entire label set.

#         label_subset =[]
#         label_subset = np.array(label_subset)
#         tmpLabels = copy.deepcopy(self.labels)
#         for i in range(num_classes):                                # num_classes 次不放回采样
#             tmp = random.choices(tmpLabels,k=1)
#             label_subset = np.concatenate((label_subset,tmp),axis=0)
#             tmpLabels.remove(tmp[0])
#         # label_subset = random.choices(self.labels, k=num_classes)  # k 次有放回采样
#         for class_idx, class_obj in enumerate(label_subset):
#             test = []
#             if class_obj not in testImage:
#               testImage[class_obj] = []
#               testLabels[class_obj] = []
#             # Use enumerated index value as a temporary label for mini-batch in
#             # few shot learning.
#             temp_labels[class_idx * shots : (class_idx + 1) * shots] = class_idx

#             # If creating a split dataset for testing, select an extra sample from each label to create the test dataset.
#             if split:
#                 test_labels[class_idx] = class_idx
#                 images_to_split = random.choices(
#                     self.data[label_subset[class_idx]], k=shots + 1   # 选出shot + 1个data
#                 )

#                 test_images[class_idx] = images_to_split[-1]
#                 temp_images[
#                     class_idx * shots : (class_idx + 1) * shots
#                 ] = images_to_split[:-1]
#             else:
#                 # For each index in the randomly selected label_subset, sample the
#                 # necessary number of images.
#                 temp_images[
#                     class_idx * shots : (class_idx + 1) * shots
#                 ] = random.choices(self.data[label_subset[class_idx]], k=shots)

#         dataset = tf.data.Dataset.from_tensor_slices(
#             (temp_images.astype(np.float32), temp_labels.astype(np.int32))
#         )
#         dataset = dataset.shuffle(100).batch(batch_size).repeat(repetitions)  #打乱，喂入batch size，迭代repetitions次
#         if split:
#             return dataset, test_images, test_labels
#         return dataset

# %%
# train_dataset = Dataset(training=True)
# test_dataset = Dataset(training=False)

# %%
"""
## Build the model
"""
# def conv_bn(x):
#     x = layers.Conv2D(filters=64, kernel_size=3, strides=2, padding="same")(x)
#     x = layers.BatchNormalization()(x)
#     return layers.ReLU()(x)
#
# inputs = layers.Input(shape=(2000, 39, 1))
# x = conv_bn(inputs)
# x = conv_bn(x)
# x = conv_bn(x)
# x = conv_bn(x)
# x = layers.Flatten()(x)
# outputs = layers.Dense(classes, activation="softmax")(x)
# model = keras.Model(inputs=inputs, outputs=outputs)
# Out:
# '\n## Build the model\n'

# %%
"""
## Change the model
"""
# X_input = Input(input_shape)
inputs = layers.Input(shape=(2000, 39, 1)) #, 1
X = Conv2D(filters=32, kernel_size=4, strides=1, name='conv0')(inputs) # 32
X = Activation('relu')(X)
# X = Dropout(0.3)(X)
X = MaxPooling2D(pool_size=2, strides=2, name='max_pool0')(X) #pool_size=2, strides=2 (4)

X = Conv2D(256, 4, strides=1, name='conv1')(X)  # filter setting. 64
X = Activation('relu')(X)
# X = Dropout(0.3)(X)
X = MaxPooling2D(pool_size=2, strides=2, name='max_pool01')(X)

X = Conv2D(128, 4, strides=1, name='conv11')(X)  # filter setting. #128
X = Activation('relu')(X)
# X = Dropout(0.3)(X)
X = MaxPooling2D(pool_size=2, strides=2, name='max_pool1')(X)

X = Conv2D(64, 4, strides=1, name='conv2', padding="same")(X)  # filter setting. # 256
X = Activation('relu')(X)
# X = Dropout(0.3)(X)

X = MaxPooling2D(pool_size=2, strides=2, name='max_pool')(X) #2
X = layers.Flatten()(X)
X = layers.Dense(classes, activation='softmax', name='fc')(X)
model = keras.Model(inputs=inputs, outputs=X, name='VoiceChestModel_Keras')

model.compile(metrics=['accuracy'])
optimizer = keras.optimizers.SGD(learning_rate=learning_rate)

# %%
# """
# ## Train the model
# """
# # allData, allLabels = Func_ReadAllData.loadAllData(finalPath,1,training)
# # allData = np.expand_dims(allData, axis=3)
# # tmpAllLabels = []
# # for label in allLabels:
# #   tmpAllLabels.append(ord(label)-65)

# # tmpAllLabels = np.array(tmpAllLabels)
# import os
# training = []
# testing = []
# labelAcc = {}
# labelSum = {}
# count = 0
# print("开始")
# # start_iter = 0
# start_iter = len(training)
# for meta_iter in range(1054,meta_iters):
  
#   frac_done = meta_iter / meta_iters
#   cur_meta_step_size = (1 - frac_done) * meta_step_size 

#   # Temporarily save the weights from the model.
#   old_vars = model.get_weights()
#   # Get a sample from the full dataset. Train the few-shot.
#   mini_dataset = train_dataset.get_mini_dataset(
#       inner_batch_size, inner_iters, train_shots, classes
#   )

#   for images, labels in mini_dataset: #？
#     with tf.GradientTape() as tape:
#       preds = model(images)
#       loss = keras.losses.sparse_categorical_crossentropy(labels, preds)
#     grads = tape.gradient(target=loss, sources=model.trainable_weights) 
#     optimizer.apply_gradients(zip(grads, model.trainable_weights))
#   new_vars = model.get_weights()
#   # Perform SGD for the meta step.  SGD：对每个样本进行更新
#   for var in range(len(new_vars)):
#     new_vars[var] = old_vars[var] + (
#         (new_vars[var] - old_vars[var]) * cur_meta_step_size)
  
#   # After the meta-learning step, reload the newly-trained weights into the model.
#   model.set_weights(new_vars)


#   # Evaluation loop
#   if meta_iter % eval_interval == 0:
#     accuracies = []
#     for dataset in (train_dataset, test_dataset):
#       count+=1
#       # Sample a mini dataset from the full dataset.
#       train_set, test_images, test_labels = dataset.get_mini_dataset(
#         eval_batch_size, eval_iters, shots, classes, split=True)
#       # print(len(train_set),len(test_images),len(test_labels))
#       old_vars = model.get_weights()
#       # Train on the samples and get the resulting accuracies.
#       for images, labels in train_set:
#         # print(len(images),len(labels))
#         with tf.GradientTape() as tape:
#           preds = model(images)
#           loss = keras.losses.sparse_categorical_crossentropy(labels, preds)
#         grads = tape.gradient(target=loss, sources=model.trainable_weights)
#         optimizer.apply_gradients(zip(grads, model.trainable_weights))
#       test_preds = model.predict(test_images)
#       test_preds = tf.argmax(test_preds).numpy()
#       # print("labels:{}, preds:{}".format(test_labels,test_preds))

#       # test_loss, test_acc= model.evaluate(allData,tmpAllLabels)
#       # print(test_loss,test_acc)
      
#       num_correct = (test_preds == test_labels).sum()
#       # Reset the weights after getting the evaluation accuracies.
#       model.set_weights(old_vars)
#       accuracies.append(num_correct / classes)
#     training.append(accuracies[0])
#     testing.append(accuracies[1])

#     if meta_iter % 10 == 0:
      
#       print(
#           "batch %d: train=%f test=%f" % (meta_iter, accuracies[0], accuracies[1])
#       )
#       np.save(os.path.join("checkpoint","traing1.npy"),training)
#       np.save(os.path.join("checkpoint","testing1.npy"),testing)

#     #保存模型
#     if meta_iter % 100 == 0:
#       ModelName = os.path.join("checkpoint","model1.h5")
#       model.save(ModelName)
    
#     if meta_iter % 1999 == 0:
#       ModelName = os.path.join("checkpoint","model1.h5")
#       model.save(ModelName)

# %%
# # First, some preprocessing to smooth the training and testing arrays for display.
# import matplotlib.pyplot as plt
# window_length = 200
# train_s = np.r_[
#     training[window_length - 1 : 0 : -1], training, training[-1:-window_length:-1]
# ]
# test_s = np.r_[
#     testing[window_length - 1 : 0 : -1], testing, testing[-1:-window_length:-1]
# ]
# w = np.hamming(window_length)
# train_y = np.convolve(w / w.sum(), train_s, mode="valid") # Numpy 中的卷积函数
# test_y = np.convolve(w / w.sum(), test_s, mode="valid")

# # Display the training accuracies.
# x = np.arange(0, len(train_y), 1)
# plt.plot(x, train_y, x, test_y)
# plt.legend(["train","test"])
# plt.grid()

# %%
import copy
test_size = 5
class testDataset:
    # This class will facilitate the creation of a few-shot dataset
    # from Collected data that can be sampled from quickly while also
    # allowing to create new labels at the same time.
    def __init__(self, training):
        self.data = {}
        self.test_data = {}
        data_train, labels_train = ReadData.loadData(startPath="split",training=training)
        data_test, labels_test = ReadData.loadData(startPath=os.path.join("Set2"),training=training)
        for data_tmp, label_tmp in zip(data_train, labels_train):
            data_tmp = np.expand_dims(data_tmp, axis=2)
            if label_tmp not in self.data:
                self.data[label_tmp] = []
            self.data[label_tmp].append(data_tmp)
            self.labels = list(self.data.keys())
        
        for data_tmp, label_tmp in zip(data_test, labels_test):
            data_tmp = np.expand_dims(data_tmp, axis=2)
            if label_tmp not in self.test_data:
                self.test_data[label_tmp] = []
            self.test_data[label_tmp].append(data_tmp)
            self.test_labels = list(self.test_data.keys())

            

    def get_mini_dataset(
        self, batch_size, repetitions, shots, num_classes, name, situation, split=False, test=False
    ):
        testImage = {}
        testLabels = {}
        temp_labels = np.zeros(shape=(num_classes * shots))
        temp_images = np.zeros(shape=(num_classes * shots, 2000, 39, 1))
        if split:
            keys = [0 for i in range(num_classes)]
            test_labels = np.zeros(shape=(num_classes))
            test_images = np.zeros(shape=(num_classes, 2000, 39, 1))

        # Get a random subset of labels from the entire label set.
        # label_subset = random.choices(self.labels, k=num_classes)  # k 次有放回采样
        label_subset =[]
        label_subset = np.array(label_subset)
        tmpLabels = copy.deepcopy(self.labels)
        for i in range(num_classes):                                # num_classes 次不放回采样
            tmp = random.choices(tmpLabels,k=1)
            label_subset = np.concatenate((label_subset,tmp),axis=0)
            tmpLabels.remove(tmp[0])
        for class_idx, class_obj in enumerate(label_subset):
            if class_obj not in testImage:
              # testImage[class_obj] = []
              # testLabels[class_obj] = []
              testImage[class_obj] = np.zeros(shape=(test_size, 2000, 39, 1))
              testLabels[class_obj] = np.zeros(shape=(test_size))
            # Use enumerated index value as a temporary label for mini-batch in
            # few shot learning.
            temp_labels[class_idx * shots : (class_idx + 1) * shots] = class_idx

            # If creating a split dataset for testing, select an extra sample from each label to create the test dataset.
            if split:
                # test_labels[class_idx] = class_idx
                test_labels[class_idx] = class_idx
                # images_to_split = random.choices(
                #     self.data[label_subset[class_idx]], k=shots + 1   # 选出shot + 1个data
                # )
                images_to_split = self.data[label_subset[class_idx]][0:shots+1]
                
                if test:
                  keys[class_idx] = class_obj
                  print("keys:{}".format(keys))

                  if(label_subset[class_idx]==name):
                    print(label_subset[class_idx]+"_"+situation)
                    testImage[class_obj] = random.choices(self.test_data[label_subset[class_idx]+"_"+situation],k=test_size)
                    testLabels[class_obj][0:] = class_idx 
                  else:
                    testImage[class_obj] = random.choices(self.data[label_subset[class_idx]][shots+1:],k=test_size)
                    testLabels[class_obj][0:] = class_idx
                   
                  # testImage[class_obj] = random.choices(self.data[label_subset[class_idx]][shots+1:],k=test_size)
                  # testLabels[class_obj][0:] = class_idx 

                  

                test_images[class_idx] = images_to_split[-1]
                temp_images[
                    class_idx * shots : (class_idx + 1) * shots
                ] = images_to_split[:-1]
            else:
                # For each index in the randomly selected label_subset, sample the
                # necessary number of images.
                temp_images[
                    class_idx * shots : (class_idx + 1) * shots
                ] = random.choices(self.data[label_subset[class_idx]], k=shots)

        # print(keys)
        dataset = tf.data.Dataset.from_tensor_slices(
            (temp_images.astype(np.float32), temp_labels.astype(np.int32))
        )
        dataset = dataset.shuffle(100).batch(batch_size).repeat(repetitions)  #打乱，喂入batch size，迭代repetitions次
        if test:
          tmpImage = []
          tmpLabels = []
          # print(len(list(testLabels.values())[0]))
          l = len(list(testLabels.values())[0])
          # print(l)
          for i in range(l):
            for k in label_subset:
              # print("i:{},lemgth:{}".format(i,len(list(testImage[k]))))
              # print("length:{},idx:{}".format(len(list(testImage[k])),i))
              tmpImage.append(list(testImage[k])[i])
              tmpLabels.append(list(testLabels[k])[i])
          # print(len(tmpImage))
          tmpImage = np.array(tmpImage)
          tmpLabels = np.array(tmpLabels)
          testset = tf.data.Dataset.from_tensor_slices((tmpImage.astype(np.float32), tmpLabels.astype(np.float32)))
          testset = testset.batch(num_classes)
          keys = np.array(keys)
          return dataset, test_images, test_labels, keys, testset
        if split:
            return dataset, test_images, test_labels
        return dataset

# %%
testSet = testDataset(False)
# Out:
# personlist:['QinDang', 'XueMeng', 'ZSF', 'LXR', 'LTM', 'ChenChangXin', 'GuXiang']
# QinDang
# /content/drive/.shortcut-targets-by-id/1dru5PCdCB6aT1Kb-75g8GYG37BEdecQR/Proj/ReadData.py:11: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   nda = np.array(data).shape[0]
# XueMeng
# ZSF
# LXR
# LTM
# ChenChangXin
# GuXiang
# /content/drive/.shortcut-targets-by-id/1dru5PCdCB6aT1Kb-75g8GYG37BEdecQR/Proj/ReadData.py:67: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   dataValue = np.array(dataValue)
# /content/drive/.shortcut-targets-by-id/1dru5PCdCB6aT1Kb-75g8GYG37BEdecQR/Proj/ReadData.py:68: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   labelsValue = np.array(labelsValue)
# personlist:['ChenChangXin_65db_MATE40PRO', 'ChenChangXin_55db_MATE40PRO', 'ChenChangXin_50db_MATE40PRO']
# ChenChangXin_65db_MATE40PRO
# ChenChangXin_55db_MATE40PRO
# ChenChangXin_50db_MATE40PRO

# %%
# trainSet = testDataset(True)

# %%
model = tf.keras.models.load_model("checkpoint/model1.h5")

# %%
# print(testSet.labels)

# %%
number = 400
acc = {}
# for shots in range(1,21,1):
#   print("shots:{}".format(shots))
shots=20
# test_size = 45

all_count = {}  #保存各个类被抽取出的总次数
label_dic = {}  #保存各个类被抽取出来后预测正确的次数，与上面的总次数相除暂定为预测的准确度
for i in range(number):
  testing = []
  train_set, test_images, test_labels, keys, test_set = testSet.get_mini_dataset(
        eval_batch_size, eval_iters, shots, classes, name="ChenChangXin", situation="65db_MATE40PRO", split=True, test=True
    )
  # print(test_set)
  for l in keys:
    if l not in label_dic:
      label_dic[l]=0
    if l not in all_count:
      all_count[l]=0
  old_vars1 = model.get_weights()
  # train
  for images, labels in train_set:
    # print(labels)
    with tf.GradientTape() as tape:
        preds = model(images)
        loss = keras.losses.sparse_categorical_crossentropy(labels, preds)
    # print(loss)
    # print("labels:{}, preds:{}".format(labels,preds))
    grads = tape.gradient(loss, model.trainable_weights)
    optimizer.apply_gradients(zip(grads, model.trainable_weights))
  test_preds = model.predict(test_images)
  test_preds = tf.argmax(test_preds).numpy()
  # if(i%50==0):
  #   print(i)
  print(i)
  # print("labels:{}, preds:{}".format(test_labels,test_preds))
  # test
  for images, labels in test_set:
      old_vars2 = model.get_weights()
      for label in labels:
        # print(label.numpy())
        all_count[keys[label.numpy().astype(int)]]+=1 
      preds = model.predict(images)
      preds = tf.argmax(preds).numpy()
      print("labels:{}, preds:{}".format(labels,preds))
      flags = (labels==preds)
      num_correct = flags.numpy().sum()
      testing.append(num_correct/classes)
      for idx, flag in enumerate(flags):
        if flag:
          label_dic[keys[idx]]+=1
      model.set_weights(old_vars2)
  model.set_weights(old_vars1)
result = {}
for key in label_dic.keys():
  result[key] = (label_dic[key]/all_count[key])*100
  print("label:{},  抽取出来的总次数:{},  其中预测正确的次数:{},  acc:{:.2f}%".format(key,all_count[key],label_dic[key],(label_dic[key]/all_count[key])*100))
# Out:
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'GuXiang', 0]
# keys:['XueMeng', 'GuXiang', 'LTM']
# 0
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'QinDang', 0]
# keys:['ZSF', 'QinDang', 'LTM']
# 1
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'XueMeng', 0]
# keys:['QinDang', 'XueMeng', 'LTM']
# 2
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'GuXiang', 0]
# keys:['XueMeng', 'GuXiang', 'LTM']
# 3
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'ZSF', 0]
# keys:['LXR', 'ZSF', 'GuXiang']
# 4
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'LTM', 0]
# keys:['XueMeng', 'LTM', 'ZSF']
# 5
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ZSF', 0]
# keys:['GuXiang', 'ZSF', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 6
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'QinDang', 0]
# keys:['ZSF', 'QinDang', 'XueMeng']
# 7
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 1 2]
# keys:['ChenChangXin', 0, 0]
# ChenChangXin_65db_MATE40PRO
# keys:['ChenChangXin', 'ZSF', 0]
# keys:['ChenChangXin', 'ZSF', 'LXR']
# 8
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'XueMeng', 0]
# keys:['LTM', 'XueMeng', 'GuXiang']
# 9
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'LXR', 0]
# keys:['GuXiang', 'LXR', 'ZSF']
# 10
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['QinDang', 'ChenChangXin', 'LXR']
# 11
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'LTM', 0]
# keys:['XueMeng', 'LTM', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 12
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'QinDang', 0]
# keys:['GuXiang', 'QinDang', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 13
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'LXR', 0]
# keys:['QinDang', 'LXR', 'GuXiang']
# 14
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ZSF', 0]
# keys:['QinDang', 'ZSF', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 15
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 1]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'LTM', 0]
# keys:['ZSF', 'LTM', 'LXR']
# 16
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['LXR', 'ChenChangXin', 'GuXiang']
# 17
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 1]
# labels:[0. 1. 2.], preds:[0 0 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'LXR', 0]
# keys:['LTM', 'LXR', 'QinDang']
# 18
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 1]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 1]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'LTM', 0]
# keys:['QinDang', 'LTM', 'XueMeng']
# 19
# labels:[0. 1. 2.], preds:[1 2 2]
# labels:[0. 1. 2.], preds:[1 0 2]
# labels:[0. 1. 2.], preds:[1 2 2]
# labels:[0. 1. 2.], preds:[1 2 2]
# labels:[0. 1. 2.], preds:[1 2 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'QinDang', 0]
# keys:['LXR', 'QinDang', 'GuXiang']
# 20
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'ZSF', 0]
# keys:['LTM', 'ZSF', 'XueMeng']
# 21
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'LXR', 0]
# keys:['XueMeng', 'LXR', 'LTM']
# 22
# labels:[0. 1. 2.], preds:[1 2 1]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'GuXiang', 0]
# keys:['QinDang', 'GuXiang', 'LXR']
# 23
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'QinDang', 0]
# keys:['XueMeng', 'QinDang', 'LTM']
# 24
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['GuXiang', 'ChenChangXin', 'XueMeng']
# 25
# labels:[0. 1. 2.], preds:[0 0 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['XueMeng', 'ChenChangXin', 'LXR']
# 26
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 0 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'GuXiang', 0]
# keys:['LXR', 'GuXiang', 'QinDang']
# 27
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ZSF', 0]
# keys:['QinDang', 'ZSF', 'LXR']
# 28
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenChangXin', 0, 0]
# ChenChangXin_65db_MATE40PRO
# keys:['ChenChangXin', 'ZSF', 0]
# keys:['ChenChangXin', 'ZSF', 'XueMeng']
# 29
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['LXR', 'ChenChangXin', 'ZSF']
# 30
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'LTM', 0]
# keys:['ZSF', 'LTM', 'GuXiang']
# 31
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'QinDang', 0]
# keys:['XueMeng', 'QinDang', 'ZSF']
# 32
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'ZSF', 0]
# keys:['XueMeng', 'ZSF', 'QinDang']
# 33
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'LTM', 0]
# keys:['QinDang', 'LTM', 'GuXiang']
# 34
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'GuXiang', 0]
# keys:['LXR', 'GuXiang', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 35
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 1]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'LXR', 0]
# keys:['ZSF', 'LXR', 'LTM']
# 36
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'GuXiang', 0]
# keys:['QinDang', 'GuXiang', 'LTM']
# 37
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['LXR', 'ChenChangXin', 'ZSF']
# 38
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'LXR', 0]
# keys:['GuXiang', 'LXR', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 39
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['LXR', 'ChenChangXin', 'GuXiang']
# 40
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 0 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenChangXin', 0, 0]
# ChenChangXin_65db_MATE40PRO
# keys:['ChenChangXin', 'ZSF', 0]
# keys:['ChenChangXin', 'ZSF', 'XueMeng']
# 41
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'QinDang', 0]
# keys:['LXR', 'QinDang', 'ZSF']
# 42
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['GuXiang', 'ChenChangXin', 'XueMeng']
# 43
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'GuXiang', 0]
# keys:['LTM', 'GuXiang', 'LXR']
# 44
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenChangXin', 0, 0]
# ChenChangXin_65db_MATE40PRO
# keys:['ChenChangXin', 'GuXiang', 0]
# keys:['ChenChangXin', 'GuXiang', 'LXR']
# 45
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'QinDang', 0]
# keys:['GuXiang', 'QinDang', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 46
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'LXR', 0]
# keys:['QinDang', 'LXR', 'GuXiang']
# 47
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['QinDang', 'ChenChangXin', 'LXR']
# 48
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['LTM', 'ChenChangXin', 'QinDang']
# 49
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'LTM', 0]
# keys:['GuXiang', 'LTM', 'XueMeng']
# 50
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenChangXin', 0, 0]
# ChenChangXin_65db_MATE40PRO
# keys:['ChenChangXin', 'ZSF', 0]
# keys:['ChenChangXin', 'ZSF', 'XueMeng']
# 51
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ZSF', 0]
# keys:['QinDang', 'ZSF', 'GuXiang']
# 52
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'QinDang', 0]
# keys:['GuXiang', 'QinDang', 'ZSF']
# 53
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'QinDang', 0]
# keys:['LXR', 'QinDang', 'LTM']
# 54
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'ZSF', 0]
# keys:['XueMeng', 'ZSF', 'LTM']
# 55
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['ZSF', 'ChenChangXin', 'QinDang']
# 56
# labels:[0. 1. 2.], preds:[1 1 2]
# labels:[0. 1. 2.], preds:[0 0 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['XueMeng', 'ChenChangXin', 'GuXiang']
# 57
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 2]
# labels:[0. 1. 2.], preds:[0 2 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['GuXiang', 'ChenChangXin', 'ZSF']
# 58
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'XueMeng', 0]
# keys:['GuXiang', 'XueMeng', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 59
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenChangXin', 0, 0]
# ChenChangXin_65db_MATE40PRO
# keys:['ChenChangXin', 'LXR', 0]
# keys:['ChenChangXin', 'LXR', 'XueMeng']
# 60
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'GuXiang', 0]
# keys:['XueMeng', 'GuXiang', 'LTM']
# 61
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ZSF', 0]
# keys:['QinDang', 'ZSF', 'LXR']
# 62
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'LTM', 0]
# keys:['XueMeng', 'LTM', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 63
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['LTM', 'ChenChangXin', 'LXR']
# 64
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'LTM', 0]
# keys:['QinDang', 'LTM', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 65
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'ZSF', 0]
# keys:['LXR', 'ZSF', 'GuXiang']
# 66
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'ZSF', 0]
# keys:['LTM', 'ZSF', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 67
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 1]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'LTM', 0]
# keys:['ZSF', 'LTM', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 68
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'ZSF', 0]
# keys:['XueMeng', 'ZSF', 'GuXiang']
# 69
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'GuXiang', 0]
# keys:['QinDang', 'GuXiang', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 70
# labels:[0. 1. 2.], preds:[0 2 1]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 1]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'LXR', 0]
# keys:['LTM', 'LXR', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 71
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'GuXiang', 0]
# keys:['XueMeng', 'GuXiang', 'QinDang']
# 72
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'GuXiang', 0]
# keys:['ZSF', 'GuXiang', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 73
# labels:[0. 1. 2.], preds:[0 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'LXR', 0]
# keys:['LTM', 'LXR', 'GuXiang']
# 74
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['XueMeng', 'ChenChangXin', 'ZSF']
# 75
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'XueMeng', 0]
# keys:['GuXiang', 'XueMeng', 'QinDang']
# 76
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'ZSF', 0]
# keys:['XueMeng', 'ZSF', 'LXR']
# 77
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'QinDang', 0]
# keys:['LXR', 'QinDang', 'ZSF']
# 78
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'ZSF', 0]
# keys:['LTM', 'ZSF', 'LXR']
# 79
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'XueMeng', 0]
# keys:['LXR', 'XueMeng', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 80
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'QinDang', 0]
# keys:['LTM', 'QinDang', 'GuXiang']
# 81
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'LTM', 0]
# keys:['LXR', 'LTM', 'XueMeng']
# 82
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ZSF', 0]
# keys:['QinDang', 'ZSF', 'GuXiang']
# 83
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'LTM', 0]
# keys:['XueMeng', 'LTM', 'ZSF']
# 84
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenChangXin', 0, 0]
# ChenChangXin_65db_MATE40PRO
# keys:['ChenChangXin', 'LTM', 0]
# keys:['ChenChangXin', 'LTM', 'LXR']
# 85
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ZSF', 0]
# keys:['GuXiang', 'ZSF', 'QinDang']
# 86
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['GuXiang', 'ChenChangXin', 'LTM']
# 87
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['LTM', 'ChenChangXin', 'LXR']
# 88
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'LXR', 0]
# keys:['ZSF', 'LXR', 'LTM']
# 89
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'ZSF', 0]
# keys:['LTM', 'ZSF', 'GuXiang']
# 90
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'GuXiang', 0]
# keys:['ZSF', 'GuXiang', 'QinDang']
# 91
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'GuXiang', 0]
# keys:['QinDang', 'GuXiang', 'LTM']
# 92
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'LXR', 0]
# keys:['QinDang', 'LXR', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 93
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'GuXiang', 0]
# keys:['LTM', 'GuXiang', 'ZSF']
# 94
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 0 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['LXR', 'ChenChangXin', 'GuXiang']
# 95
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'LTM', 0]
# keys:['ZSF', 'LTM', 'XueMeng']
# 96
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'XueMeng', 0]
# keys:['LTM', 'XueMeng', 'QinDang']
# 97
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'ZSF', 0]
# keys:['LXR', 'ZSF', 'QinDang']
# 98
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'LTM', 0]
# keys:['GuXiang', 'LTM', 'QinDang']
# 99
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['LTM', 'ChenChangXin', 'XueMeng']
# 100
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'ZSF', 0]
# keys:['XueMeng', 'ZSF', 'GuXiang']
# 101
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ZSF', 0]
# keys:['QinDang', 'ZSF', 'LTM']
# 102
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'GuXiang', 0]
# keys:['QinDang', 'GuXiang', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 103
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'XueMeng', 0]
# keys:['LXR', 'XueMeng', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 104
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'GuXiang', 0]
# keys:['LTM', 'GuXiang', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 105
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 1]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'LTM', 0]
# keys:['XueMeng', 'LTM', 'LXR']
# 106
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'LTM', 0]
# keys:['LXR', 'LTM', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 107
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenChangXin', 0, 0]
# ChenChangXin_65db_MATE40PRO
# keys:['ChenChangXin', 'LTM', 0]
# keys:['ChenChangXin', 'LTM', 'GuXiang']
# 108
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'XueMeng', 0]
# keys:['GuXiang', 'XueMeng', 'ZSF']
# 109
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'LXR', 0]
# keys:['ZSF', 'LXR', 'LTM']
# 110
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'QinDang', 0]
# keys:['LTM', 'QinDang', 'LXR']
# 111
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'GuXiang', 0]
# keys:['LTM', 'GuXiang', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 112
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 1]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenChangXin', 0, 0]
# ChenChangXin_65db_MATE40PRO
# keys:['ChenChangXin', 'QinDang', 0]
# keys:['ChenChangXin', 'QinDang', 'GuXiang']
# 113
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['LTM', 'ChenChangXin', 'GuXiang']
# 114
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'LTM', 0]
# keys:['LXR', 'LTM', 'ZSF']
# 115
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'LXR', 0]
# keys:['ZSF', 'LXR', 'GuXiang']
# 116
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['QinDang', 'ChenChangXin', 'GuXiang']
# 117
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 1]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'ZSF', 0]
# keys:['XueMeng', 'ZSF', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 118
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['QinDang', 'ChenChangXin', 'LTM']
# 119
# labels:[0. 1. 2.], preds:[0 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'LTM', 0]
# keys:['GuXiang', 'LTM', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 120
# labels:[0. 1. 2.], preds:[2 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 1 0]
# keys:['LXR', 0, 0]
# keys:['LXR', 'QinDang', 0]
# keys:['LXR', 'QinDang', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 121
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['GuXiang', 'ChenChangXin', 'ZSF']
# 122
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 1]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['GuXiang', 'ChenChangXin', 'LXR']
# 123
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'QinDang', 0]
# keys:['LXR', 'QinDang', 'XueMeng']
# 124
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'LTM', 0]
# keys:['ZSF', 'LTM', 'LXR']
# 125
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'ZSF', 0]
# keys:['XueMeng', 'ZSF', 'GuXiang']
# 126
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'QinDang', 0]
# keys:['ZSF', 'QinDang', 'LXR']
# 127
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'XueMeng', 0]
# keys:['ZSF', 'XueMeng', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 128
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'XueMeng', 0]
# keys:['LTM', 'XueMeng', 'ZSF']
# 129
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenChangXin', 0, 0]
# ChenChangXin_65db_MATE40PRO
# keys:['ChenChangXin', 'XueMeng', 0]
# keys:['ChenChangXin', 'XueMeng', 'LXR']
# 130
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'GuXiang', 0]
# keys:['QinDang', 'GuXiang', 'XueMeng']
# 131
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ZSF', 0]
# keys:['GuXiang', 'ZSF', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 132
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 1]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'LXR', 0]
# keys:['LTM', 'LXR', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 133
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'XueMeng', 0]
# keys:['ZSF', 'XueMeng', 'QinDang']
# 134
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenChangXin', 0, 0]
# ChenChangXin_65db_MATE40PRO
# keys:['ChenChangXin', 'LXR', 0]
# keys:['ChenChangXin', 'LXR', 'LTM']
# 135
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 1 0]
# keys:['LXR', 0, 0]
# keys:['LXR', 'ZSF', 0]
# keys:['LXR', 'ZSF', 'GuXiang']
# 136
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenChangXin', 0, 0]
# ChenChangXin_65db_MATE40PRO
# keys:['ChenChangXin', 'GuXiang', 0]
# keys:['ChenChangXin', 'GuXiang', 'XueMeng']
# 137
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 1 2]
# labels:[0. 1. 2.], preds:[1 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'LXR', 0]
# keys:['LTM', 'LXR', 'ZSF']
# 138
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'LXR', 0]
# keys:['LTM', 'LXR', 'QinDang']
# 139
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'QinDang', 0]
# keys:['GuXiang', 'QinDang', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 140
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'GuXiang', 0]
# keys:['LTM', 'GuXiang', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 141
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 1]
# keys:['ChenChangXin', 0, 0]
# ChenChangXin_65db_MATE40PRO
# keys:['ChenChangXin', 'LTM', 0]
# keys:['ChenChangXin', 'LTM', 'GuXiang']
# 142
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'XueMeng', 0]
# keys:['ZSF', 'XueMeng', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 143
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'LTM', 0]
# keys:['ZSF', 'LTM', 'GuXiang']
# 144
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ZSF', 0]
# keys:['GuXiang', 'ZSF', 'LTM']
# 145
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['ZSF', 'ChenChangXin', 'LXR']
# 146
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 1 0]
# keys:['LXR', 0, 0]
# keys:['LXR', 'ZSF', 0]
# keys:['LXR', 'ZSF', 'LTM']
# 147
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['GuXiang', 'ChenChangXin', 'ZSF']
# 148
# labels:[0. 1. 2.], preds:[0 0 1]
# labels:[0. 1. 2.], preds:[0 2 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 0 2]
# labels:[0. 1. 2.], preds:[2 1 2]
# keys:['ChenChangXin', 0, 0]
# ChenChangXin_65db_MATE40PRO
# keys:['ChenChangXin', 'LTM', 0]
# keys:['ChenChangXin', 'LTM', 'ZSF']
# 149
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'LTM', 0]
# keys:['ZSF', 'LTM', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 150
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'LXR', 0]
# keys:['XueMeng', 'LXR', 'LTM']
# 151
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'QinDang', 0]
# keys:['LXR', 'QinDang', 'XueMeng']
# 152
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'LTM', 0]
# keys:['GuXiang', 'LTM', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 153
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 0]
# labels:[0. 1. 2.], preds:[0 1 0]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'GuXiang', 0]
# keys:['XueMeng', 'GuXiang', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 154
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ZSF', 0]
# keys:['QinDang', 'ZSF', 'XueMeng']
# 155
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['XueMeng', 'ChenChangXin', 'LTM']
# 156
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['XueMeng', 'ChenChangXin', 'LTM']
# 157
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['XueMeng', 'ChenChangXin', 'ZSF']
# 158
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'XueMeng', 0]
# keys:['LXR', 'XueMeng', 'GuXiang']
# 159
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'LXR', 0]
# keys:['XueMeng', 'LXR', 'LTM']
# 160
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'ZSF', 0]
# keys:['XueMeng', 'ZSF', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 161
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'GuXiang', 0]
# keys:['XueMeng', 'GuXiang', 'LXR']
# 162
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'QinDang', 0]
# keys:['GuXiang', 'QinDang', 'ZSF']
# 163
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'QinDang', 0]
# keys:['ZSF', 'QinDang', 'LTM']
# 164
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'GuXiang', 0]
# keys:['ZSF', 'GuXiang', 'QinDang']
# 165
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenChangXin', 0, 0]
# ChenChangXin_65db_MATE40PRO
# keys:['ChenChangXin', 'XueMeng', 0]
# keys:['ChenChangXin', 'XueMeng', 'LTM']
# 166
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'GuXiang', 0]
# keys:['QinDang', 'GuXiang', 'LTM']
# 167
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 0 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['GuXiang', 'ChenChangXin', 'LXR']
# 168
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'LXR', 0]
# keys:['LTM', 'LXR', 'ZSF']
# 169
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'LXR', 0]
# keys:['LTM', 'LXR', 'QinDang']
# 170
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'LTM', 0]
# keys:['GuXiang', 'LTM', 'QinDang']
# 171
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['ZSF', 'ChenChangXin', 'XueMeng']
# 172
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'ZSF', 0]
# keys:['LTM', 'ZSF', 'XueMeng']
# 173
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'XueMeng', 0]
# keys:['GuXiang', 'XueMeng', 'LTM']
# 174
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'LXR', 0]
# keys:['QinDang', 'LXR', 'LTM']
# 175
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenChangXin', 0, 0]
# ChenChangXin_65db_MATE40PRO
# keys:['ChenChangXin', 'ZSF', 0]
# keys:['ChenChangXin', 'ZSF', 'XueMeng']
# 176
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['GuXiang', 'ChenChangXin', 'QinDang']
# 177
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ZSF', 0]
# keys:['GuXiang', 'ZSF', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 178
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# ...
# keys:['ChenChangXin', 'QinDang', 0]
# keys:['ChenChangXin', 'QinDang', 'ZSF']
# 341
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'GuXiang', 0]
# keys:['QinDang', 'GuXiang', 'LTM']
# 342
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'XueMeng', 0]
# keys:['QinDang', 'XueMeng', 'GuXiang']
# 343
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'GuXiang', 0]
# keys:['ZSF', 'GuXiang', 'LXR']
# 344
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'LXR', 0]
# keys:['XueMeng', 'LXR', 'GuXiang']
# 345
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'LTM', 0]
# keys:['GuXiang', 'LTM', 'XueMeng']
# 346
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'XueMeng', 0]
# keys:['GuXiang', 'XueMeng', 'LXR']
# 347
# labels:[0. 1. 2.], preds:[2 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'XueMeng', 0]
# keys:['LTM', 'XueMeng', 'QinDang']
# 348
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['ZSF', 'ChenChangXin', 'LXR']
# 349
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'LXR', 0]
# keys:['GuXiang', 'LXR', 'QinDang']
# 350
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['QinDang', 'ChenChangXin', 'XueMeng']
# 351
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'XueMeng', 0]
# keys:['LTM', 'XueMeng', 'QinDang']
# 352
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['LXR', 'ChenChangXin', 'XueMeng']
# 353
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'ZSF', 0]
# keys:['LXR', 'ZSF', 'XueMeng']
# 354
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'ZSF', 0]
# keys:['LTM', 'ZSF', 'QinDang']
# 355
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['ZSF', 'ChenChangXin', 'QinDang']
# 356
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 0 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'XueMeng', 0]
# keys:['GuXiang', 'XueMeng', 'LTM']
# 357
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'XueMeng', 0]
# keys:['LXR', 'XueMeng', 'LTM']
# 358
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'LXR', 0]
# keys:['ZSF', 'LXR', 'QinDang']
# 359
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'LXR', 0]
# keys:['LTM', 'LXR', 'QinDang']
# 360
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'ZSF', 0]
# keys:['QinDang', 'ZSF', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 361
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'LXR', 0]
# keys:['GuXiang', 'LXR', 'QinDang']
# 362
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenChangXin', 0, 0]
# ChenChangXin_65db_MATE40PRO
# keys:['ChenChangXin', 'GuXiang', 0]
# keys:['ChenChangXin', 'GuXiang', 'LXR']
# 363
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ZSF', 0]
# keys:['GuXiang', 'ZSF', 'LXR']
# 364
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[1 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'XueMeng', 0]
# keys:['LTM', 'XueMeng', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 365
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'XueMeng', 0]
# keys:['ZSF', 'XueMeng', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 366
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['GuXiang', 'ChenChangXin', 'LXR']
# 367
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 0 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'XueMeng', 0]
# keys:['ZSF', 'XueMeng', 'GuXiang']
# 368
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 1]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'LXR', 0]
# keys:['GuXiang', 'LXR', 'QinDang']
# 369
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['LTM', 'ChenChangXin', 'LXR']
# 370
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'XueMeng', 0]
# keys:['LTM', 'XueMeng', 'GuXiang']
# 371
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'XueMeng', 0]
# keys:['LTM', 'XueMeng', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 372
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'QinDang', 0]
# keys:['ZSF', 'QinDang', 'LXR']
# 373
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'GuXiang', 0]
# keys:['QinDang', 'GuXiang', 'ZSF']
# 374
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'LTM', 0]
# keys:['GuXiang', 'LTM', 'LXR']
# 375
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'LTM', 0]
# keys:['ZSF', 'LTM', 'QinDang']
# 376
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 2 1]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'GuXiang', 0]
# keys:['XueMeng', 'GuXiang', 'ZSF']
# 377
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenChangXin', 0, 0]
# ChenChangXin_65db_MATE40PRO
# keys:['ChenChangXin', 'QinDang', 0]
# keys:['ChenChangXin', 'QinDang', 'GuXiang']
# 378
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'QinDang', 0]
# keys:['LTM', 'QinDang', 'LXR']
# 379
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'LTM', 0]
# keys:['LXR', 'LTM', 'XueMeng']
# 380
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenChangXin', 0, 0]
# ChenChangXin_65db_MATE40PRO
# keys:['ChenChangXin', 'XueMeng', 0]
# keys:['ChenChangXin', 'XueMeng', 'LTM']
# 381
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ZSF', 0, 0]
# keys:['ZSF', 'LXR', 0]
# keys:['ZSF', 'LXR', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 382
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'GuXiang', 0]
# keys:['LTM', 'GuXiang', 'LXR']
# 383
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'GuXiang', 0]
# keys:['LTM', 'GuXiang', 'LXR']
# 384
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'QinDang', 0]
# keys:['LTM', 'QinDang', 'LXR']
# 385
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'GuXiang', 0]
# keys:['XueMeng', 'GuXiang', 'QinDang']
# 386
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'LXR', 0]
# keys:['XueMeng', 'LXR', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 387
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'LTM', 0]
# keys:['XueMeng', 'LTM', 'QinDang']
# 388
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'GuXiang', 0]
# keys:['XueMeng', 'GuXiang', 'ZSF']
# 389
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 0 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'QinDang', 0]
# keys:['LTM', 'QinDang', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 390
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LXR', 0, 0]
# keys:['LXR', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['LXR', 'ChenChangXin', 'LTM']
# 391
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['LTM', 0, 0]
# keys:['LTM', 'LXR', 0]
# keys:['LTM', 'LXR', 'XueMeng']
# 392
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'XueMeng', 0]
# keys:['QinDang', 'XueMeng', 'ChenChangXin']
# ChenChangXin_65db_MATE40PRO
# 393
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'QinDang', 0]
# keys:['XueMeng', 'QinDang', 'LXR']
# 394
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['ChenChangXin', 0, 0]
# ChenChangXin_65db_MATE40PRO
# keys:['ChenChangXin', 'QinDang', 0]
# keys:['ChenChangXin', 'QinDang', 'XueMeng']
# 395
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'ChenChangXin', 0]
# ChenChangXin_65db_MATE40PRO
# keys:['XueMeng', 'ChenChangXin', 'LXR']
# 396
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[2 1 0]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['XueMeng', 0, 0]
# keys:['XueMeng', 'ZSF', 0]
# keys:['XueMeng', 'ZSF', 'GuXiang']
# 397
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['QinDang', 0, 0]
# keys:['QinDang', 'GuXiang', 0]
# keys:['QinDang', 'GuXiang', 'XueMeng']
# 398
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# keys:['GuXiang', 0, 0]
# keys:['GuXiang', 'XueMeng', 0]
# keys:['GuXiang', 'XueMeng', 'QinDang']
# 399
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# labels:[0. 1. 2.], preds:[0 1 2]
# label:XueMeng,  抽取出来的总次数:835,  其中预测正确的次数:830,  acc:99.40%
# label:GuXiang,  抽取出来的总次数:940,  其中预测正确的次数:891,  acc:94.79%
# label:LTM,  抽取出来的总次数:860,  其中预测正确的次数:851,  acc:98.95%
# label:ZSF,  抽取出来的总次数:865,  其中预测正确的次数:854,  acc:98.73%
# label:QinDang,  抽取出来的总次数:765,  其中预测正确的次数:756,  acc:98.82%
# label:LXR,  抽取出来的总次数:890,  其中预测正确的次数:878,  acc:98.65%
# label:ChenChangXin,  抽取出来的总次数:845,  其中预测正确的次数:792,  acc:93.73%

# %%
import os
dir = './Set2/test/FCK_20cm_oneplus'
print(os.path.exists(dir))
# Out:
# False

# %%
import os
import time
dir = './split/test/ChenChangXin'
flag = os.path.exists(dir)
print("开始")
while flag!=True:
  print("一次尝试")
  flag = os.path.exists(dir)
  time.sleep(2)
print("已修改")
# Out:
# 开始
# 已修改
