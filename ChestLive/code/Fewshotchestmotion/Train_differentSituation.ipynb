# %%
# !pip install keras==2.1.2
# Out:
# Collecting keras==2.1.2
#   Downloading https://files.pythonhosted.org/packages/68/89/58ee5f56a9c26957d97217db41780ebedca3154392cb903c3f8a08a52208/Keras-2.1.2-py2.py3-none-any.whl (304kB)
#      |████████████████████████████████| 307kB 8.1MB/s
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras==2.1.2) (3.13)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from keras==2.1.2) (1.4.1)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras==2.1.2) (1.19.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from keras==2.1.2) (1.15.0)
# ERROR: textgenrnn 1.4.1 has requirement keras>=2.1.5, but you'll have keras 2.1.2 which is incompatible.
# Installing collected packages: keras
#   Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# Successfully installed keras-2.1.2

# %%
## authorize access to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# navigate to project directory
# %cd '/content/drive/My Drive/Colab Notebooks/Proj'
# %cd '/content/drive/My Drive/Proj/'
# Out:
# /content/drive/.shortcut-targets-by-id/1uwDLBwwarrBY7KO4nFkGzqzv6mRxU_J7/Colab Notebooks/Proj

# %%
import os
print(os.path.exists('./split/test/ZJ'))
# Out:
# False

# %%
"""
    解决：如果有100个类，如何划分，训练集、验证集和测试集。可以60个类训练、20个验证，最后20个测试。
"""
# import keras
# from keras_preprocessing import image
#import matplotlib.pyplot as plt
import numpy as np
import random
import tensorflow as tf
#import keras
#from keras import layers
# from keras_preprocessing import image
from tensorflow import keras
from tensorflow.keras import layers
#import tensorflow_datasets as tfds
import Func_ReadAllData
import ReadData
from tensorflow.keras.layers import Input, Conv1D, Activation, Dropout, MaxPooling1D, Conv2D, MaxPooling2D
import copy

import os
# import keras.backend.tensorflow_backend as KTF
# os.environ["CUDA_VISIBLE_DEVICES"]="0"
# config = tf.compat.v1.ConfigProto()
# config.gpu_options.per_process_gpu_memory_fraction = 0.8
# session = tf.compat.v1.Session(config=config)
# KTF.set_session(session)

# %%
"""
## Define the Hyperparameters
"""
learning_rate = 0.003 # 0.003
meta_step_size = 0.1 # 0.25

inner_batch_size = 25
eval_batch_size = 25

meta_iters = 2000  # 8000
eval_iters = 5
inner_iters = 4

eval_interval = 1
train_shots = 20  # 20 5
shots = 20  # 5

classes = 2  # 5

# %%
# import readData
# class Dataset:
#     # This class will facilitate the creation of a few-shot dataset
#     # from Collected data that can be sampled from quickly while also
#     # allowing to create new labels at the same time.
#     def __init__(self, training):
#         self.data = {}
#         data_train, labels_train = ReadData.loadData(startPath="split",training=training)
#         for data_tmp, label_tmp in zip(data_train, labels_train):
#             data_tmp = np.expand_dims(data_tmp, axis=2)
#             if label_tmp not in self.data:
#                 self.data[label_tmp] = []
#             self.data[label_tmp].append(data_tmp)
#             self.labels = list(self.data.keys())

            

#     def get_mini_dataset(
#         self, batch_size, repetitions, shots, num_classes, split=False, test=False
#     ):
#         testImage = {}
#         testLabels = {}
#         temp_labels = np.zeros(shape=(num_classes * shots))
#         temp_images = np.zeros(shape=(num_classes * shots, 2000, 39, 1))
#         if split:
#             keys = np.zeros(shape=(num_classes))
#             test_labels = np.zeros(shape=(num_classes))
#             test_images = np.zeros(shape=(num_classes, 2000, 39, 1))

#         # Get a random subset of labels from the entire label set.

#         label_subset =[]
#         label_subset = np.array(label_subset)
#         tmpLabels = copy.deepcopy(self.labels)
#         for i in range(num_classes):                                # num_classes 次不放回采样
#             tmp = random.choices(tmpLabels,k=1)
#             label_subset = np.concatenate((label_subset,tmp),axis=0)
#             tmpLabels.remove(tmp[0])
#         # label_subset = random.choices(self.labels, k=num_classes)  # k 次有放回采样
#         for class_idx, class_obj in enumerate(label_subset):
#             test = []
#             if class_obj not in testImage:
#               testImage[class_obj] = []
#               testLabels[class_obj] = []
#             # Use enumerated index value as a temporary label for mini-batch in
#             # few shot learning.
#             temp_labels[class_idx * shots : (class_idx + 1) * shots] = class_idx

#             # If creating a split dataset for testing, select an extra sample from each label to create the test dataset.
#             if split:
#                 test_labels[class_idx] = class_idx
#                 images_to_split = random.choices(
#                     self.data[label_subset[class_idx]], k=shots + 1   # 选出shot + 1个data
#                 )

#                 test_images[class_idx] = images_to_split[-1]
#                 temp_images[
#                     class_idx * shots : (class_idx + 1) * shots
#                 ] = images_to_split[:-1]
#             else:
#                 # For each index in the randomly selected label_subset, sample the
#                 # necessary number of images.
#                 temp_images[
#                     class_idx * shots : (class_idx + 1) * shots
#                 ] = random.choices(self.data[label_subset[class_idx]], k=shots)

#         dataset = tf.data.Dataset.from_tensor_slices(
#             (temp_images.astype(np.float32), temp_labels.astype(np.int32))
#         )
#         dataset = dataset.shuffle(100).batch(batch_size).repeat(repetitions)  #打乱，喂入batch size，迭代repetitions次
#         if split:
#             return dataset, test_images, test_labels
#         return dataset

# %%
# train_dataset = Dataset(training=True)
# test_dataset = Dataset(training=False)

# %%
"""
## Build the model
"""
# def conv_bn(x):
#     x = layers.Conv2D(filters=64, kernel_size=3, strides=2, padding="same")(x)
#     x = layers.BatchNormalization()(x)
#     return layers.ReLU()(x)
#
# inputs = layers.Input(shape=(2000, 39, 1))
# x = conv_bn(inputs)
# x = conv_bn(x)
# x = conv_bn(x)
# x = conv_bn(x)
# x = layers.Flatten()(x)
# outputs = layers.Dense(classes, activation="softmax")(x)
# model = keras.Model(inputs=inputs, outputs=outputs)
# Out:
# '\n## Build the model\n'

# %%
"""
## Change the model
"""
# X_input = Input(input_shape)
inputs = layers.Input(shape=(2000, 39, 1)) #, 1
X = Conv2D(filters=32, kernel_size=4, strides=1, name='conv0')(inputs) # 32
X = Activation('relu')(X)
# X = Dropout(0.3)(X)
X = MaxPooling2D(pool_size=2, strides=2, name='max_pool0')(X) #pool_size=2, strides=2 (4)

X = Conv2D(256, 4, strides=1, name='conv1')(X)  # filter setting. 64
X = Activation('relu')(X)
# X = Dropout(0.3)(X)
X = MaxPooling2D(pool_size=2, strides=2, name='max_pool01')(X)

X = Conv2D(128, 4, strides=1, name='conv11')(X)  # filter setting. #128
X = Activation('relu')(X)
# X = Dropout(0.3)(X)
X = MaxPooling2D(pool_size=2, strides=2, name='max_pool1')(X)

X = Conv2D(64, 4, strides=1, name='conv2', padding="same")(X)  # filter setting. # 256
X = Activation('relu')(X)
# X = Dropout(0.3)(X)

X = MaxPooling2D(pool_size=2, strides=2, name='max_pool')(X) #2
X = layers.Flatten()(X)
X = layers.Dense(classes, activation='softmax', name='fc')(X)
model = keras.Model(inputs=inputs, outputs=X, name='VoiceChestModel_Keras')

model.compile(metrics=['accuracy'])
optimizer = keras.optimizers.SGD(learning_rate=learning_rate)

# %%
# """
# ## Train the model
# """
# # allData, allLabels = Func_ReadAllData.loadAllData(finalPath,1,training)
# # allData = np.expand_dims(allData, axis=3)
# # tmpAllLabels = []
# # for label in allLabels:
# #   tmpAllLabels.append(ord(label)-65)

# # tmpAllLabels = np.array(tmpAllLabels)
# import os
# training = []
# testing = []
# labelAcc = {}
# labelSum = {}
# count = 0
# print("开始")
# # start_iter = 0
# start_iter = len(training)
# for meta_iter in range(1054,meta_iters):
  
#   frac_done = meta_iter / meta_iters
#   cur_meta_step_size = (1 - frac_done) * meta_step_size 

#   # Temporarily save the weights from the model.
#   old_vars = model.get_weights()
#   # Get a sample from the full dataset. Train the few-shot.
#   mini_dataset = train_dataset.get_mini_dataset(
#       inner_batch_size, inner_iters, train_shots, classes
#   )

#   for images, labels in mini_dataset: #？
#     with tf.GradientTape() as tape:
#       preds = model(images)
#       loss = keras.losses.sparse_categorical_crossentropy(labels, preds)
#     grads = tape.gradient(target=loss, sources=model.trainable_weights) 
#     optimizer.apply_gradients(zip(grads, model.trainable_weights))
#   new_vars = model.get_weights()
#   # Perform SGD for the meta step.  SGD：对每个样本进行更新
#   for var in range(len(new_vars)):
#     new_vars[var] = old_vars[var] + (
#         (new_vars[var] - old_vars[var]) * cur_meta_step_size)
  
#   # After the meta-learning step, reload the newly-trained weights into the model.
#   model.set_weights(new_vars)


#   # Evaluation loop
#   if meta_iter % eval_interval == 0:
#     accuracies = []
#     for dataset in (train_dataset, test_dataset):
#       count+=1
#       # Sample a mini dataset from the full dataset.
#       train_set, test_images, test_labels = dataset.get_mini_dataset(
#         eval_batch_size, eval_iters, shots, classes, split=True)
#       # print(len(train_set),len(test_images),len(test_labels))
#       old_vars = model.get_weights()
#       # Train on the samples and get the resulting accuracies.
#       for images, labels in train_set:
#         # print(len(images),len(labels))
#         with tf.GradientTape() as tape:
#           preds = model(images)
#           loss = keras.losses.sparse_categorical_crossentropy(labels, preds)
#         grads = tape.gradient(target=loss, sources=model.trainable_weights)
#         optimizer.apply_gradients(zip(grads, model.trainable_weights))
#       test_preds = model.predict(test_images)
#       test_preds = tf.argmax(test_preds).numpy()
#       # print("labels:{}, preds:{}".format(test_labels,test_preds))

#       # test_loss, test_acc= model.evaluate(allData,tmpAllLabels)
#       # print(test_loss,test_acc)
      
#       num_correct = (test_preds == test_labels).sum()
#       # Reset the weights after getting the evaluation accuracies.
#       model.set_weights(old_vars)
#       accuracies.append(num_correct / classes)
#     training.append(accuracies[0])
#     testing.append(accuracies[1])

#     if meta_iter % 10 == 0:
      
#       print(
#           "batch %d: train=%f test=%f" % (meta_iter, accuracies[0], accuracies[1])
#       )
#       np.save(os.path.join("checkpoint","traing1.npy"),training)
#       np.save(os.path.join("checkpoint","testing1.npy"),testing)

#     #保存模型
#     if meta_iter % 100 == 0:
#       ModelName = os.path.join("checkpoint","model1.h5")
#       model.save(ModelName)
    
#     if meta_iter % 1999 == 0:
#       ModelName = os.path.join("checkpoint","model1.h5")
#       model.save(ModelName)

# %%
# # First, some preprocessing to smooth the training and testing arrays for display.
# import matplotlib.pyplot as plt
# window_length = 200
# train_s = np.r_[
#     training[window_length - 1 : 0 : -1], training, training[-1:-window_length:-1]
# ]
# test_s = np.r_[
#     testing[window_length - 1 : 0 : -1], testing, testing[-1:-window_length:-1]
# ]
# w = np.hamming(window_length)
# train_y = np.convolve(w / w.sum(), train_s, mode="valid") # Numpy 中的卷积函数
# test_y = np.convolve(w / w.sum(), test_s, mode="valid")

# # Display the training accuracies.
# x = np.arange(0, len(train_y), 1)
# plt.plot(x, train_y, x, test_y)
# plt.legend(["train","test"])
# plt.grid()

# %%
import copy
test_size = 5
class testDataset:
    # This class will facilitate the creation of a few-shot dataset
    # from Collected data that can be sampled from quickly while also
    # allowing to create new labels at the same time.
    def __init__(self, training):
        self.data = {}
        self.test_data = {}
        data_train, labels_train = ReadData.loadData(startPath="split",training=training)
        data_test, labels_test = ReadData.loadData(startPath=os.path.join("Set2"),training=training)
        for data_tmp, label_tmp in zip(data_train, labels_train):
            data_tmp = np.expand_dims(data_tmp, axis=2)
            if label_tmp not in self.data:
                self.data[label_tmp] = []
            self.data[label_tmp].append(data_tmp)
            self.labels = list(self.data.keys())
        
        for data_tmp, label_tmp in zip(data_test, labels_test):
            data_tmp = np.expand_dims(data_tmp, axis=2)
            if label_tmp not in self.test_data:
                self.test_data[label_tmp] = []
            self.test_data[label_tmp].append(data_tmp)
            self.test_labels = list(self.test_data.keys())

            

    def get_mini_dataset(
        self, batch_size, repetitions, shots, num_classes, name, situation, split=False, test=False
    ):
        testImage = {}
        testLabels = {}
        temp_labels = np.zeros(shape=(num_classes * shots))
        temp_images = np.zeros(shape=(num_classes * shots, 2000, 39, 1))
        if split:
            keys = [0 for i in range(num_classes)]
            test_labels = np.zeros(shape=(num_classes))
            test_images = np.zeros(shape=(num_classes, 2000, 39, 1))

        # Get a random subset of labels from the entire label set.
        # label_subset = random.choices(self.labels, k=num_classes)  # k 次有放回采样
        label_subset =[]
        label_subset = np.array(label_subset)
        tmpLabels = copy.deepcopy(self.labels)
        for i in range(num_classes):                                # num_classes 次不放回采样
            tmp = random.choices(tmpLabels,k=1)
            label_subset = np.concatenate((label_subset,tmp),axis=0)
            tmpLabels.remove(tmp[0])
        for class_idx, class_obj in enumerate(label_subset):
            if class_obj not in testImage:
              # testImage[class_obj] = []
              # testLabels[class_obj] = []
              testImage[class_obj] = np.zeros(shape=(test_size, 2000, 39, 1))
              testLabels[class_obj] = np.zeros(shape=(test_size))
            # Use enumerated index value as a temporary label for mini-batch in
            # few shot learning.
            temp_labels[class_idx * shots : (class_idx + 1) * shots] = class_idx

            # If creating a split dataset for testing, select an extra sample from each label to create the test dataset.
            if split:
                # test_labels[class_idx] = class_idx
                test_labels[class_idx] = class_idx
                # images_to_split = random.choices(
                #     self.data[label_subset[class_idx]], k=shots + 1   # 选出shot + 1个data
                # )
                images_to_split = self.data[label_subset[class_idx]][0:shots+1]
                
                if test:
                  keys[class_idx] = class_obj
                  print("keys:{}".format(keys))

                  if(label_subset[class_idx]==name):
                    print(label_subset[class_idx]+"_"+situation)
                    testImage[class_obj] = random.choices(self.test_data[label_subset[class_idx]+"_"+situation],k=test_size)
                    testLabels[class_obj][0:] = class_idx 
                  else:
                    testImage[class_obj] = random.choices(self.data[label_subset[class_idx]][shots+1:],k=test_size)
                    testLabels[class_obj][0:] = class_idx
                   
                  # testImage[class_obj] = random.choices(self.data[label_subset[class_idx]][shots+1:],k=test_size)
                  # testLabels[class_obj][0:] = class_idx 

                  

                test_images[class_idx] = images_to_split[-1]
                temp_images[
                    class_idx * shots : (class_idx + 1) * shots
                ] = images_to_split[:-1]
            else:
                # For each index in the randomly selected label_subset, sample the
                # necessary number of images.
                temp_images[
                    class_idx * shots : (class_idx + 1) * shots
                ] = random.choices(self.data[label_subset[class_idx]], k=shots)

        # print(keys)
        dataset = tf.data.Dataset.from_tensor_slices(
            (temp_images.astype(np.float32), temp_labels.astype(np.int32))
        )
        dataset = dataset.shuffle(100).batch(batch_size).repeat(repetitions)  #打乱，喂入batch size，迭代repetitions次
        if test:
          tmpImage = []
          tmpLabels = []
          # print(len(list(testLabels.values())[0]))
          l = len(list(testLabels.values())[0])
          # print(l)
          for i in range(l):
            for k in label_subset:
              # print("i:{},lemgth:{}".format(i,len(list(testImage[k]))))
              # print("length:{},idx:{}".format(len(list(testImage[k])),i))
              tmpImage.append(list(testImage[k])[i])
              tmpLabels.append(list(testLabels[k])[i])
          # print(len(tmpImage))
          tmpImage = np.array(tmpImage)
          tmpLabels = np.array(tmpLabels)
          testset = tf.data.Dataset.from_tensor_slices((tmpImage.astype(np.float32), tmpLabels.astype(np.float32)))
          testset = testset.batch(num_classes)
          keys = np.array(keys)
          return dataset, test_images, test_labels, keys, testset
        if split:
            return dataset, test_images, test_labels
        return dataset

# %%
testSet = testDataset(False)
# Out:
# personlist:['ChenZhiPeng', 'QinDang', 'XueMeng', 'XZQ', 'WZY', 'LengChao', 'MengZiYun']
# ChenZhiPeng
# /content/drive/.shortcut-targets-by-id/1uwDLBwwarrBY7KO4nFkGzqzv6mRxU_J7/Colab Notebooks/Proj/ReadData.py:11: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   nda = np.array(data).shape[0]
# QinDang
# XueMeng
# XZQ
# WZY
# LengChao
# MengZiYun
# /content/drive/.shortcut-targets-by-id/1uwDLBwwarrBY7KO4nFkGzqzv6mRxU_J7/Colab Notebooks/Proj/ReadData.py:67: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   dataValue = np.array(dataValue)
# /content/drive/.shortcut-targets-by-id/1uwDLBwwarrBY7KO4nFkGzqzv6mRxU_J7/Colab Notebooks/Proj/ReadData.py:68: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   labelsValue = np.array(labelsValue)
# personlist:['ChenZhiPeng_走动_mate30', 'ChenZhiPeng_平躺床_mate30', 'ChenZhiPeng_5cm_Mate30', 'ChenZhiPeng_仰躺_mate30', 'ChenZhiPeng_OKGoogle_mate30', 'ChenZhiPeng_10cm_Mate30', 'ChenZhiPeng_20cm_Mate30', 'ChenZhiPeng_25cm_Mate30', 'ChenZhiPeng_30cm_Mate30', 'ChenZhiPeng_站着_mate30']
# ChenZhiPeng_走动_mate30
# ChenZhiPeng_平躺床_mate30
# ChenZhiPeng_5cm_Mate30
# ChenZhiPeng_仰躺_mate30
# ChenZhiPeng_OKGoogle_mate30
# ChenZhiPeng_10cm_Mate30
# ChenZhiPeng_20cm_Mate30
# ChenZhiPeng_25cm_Mate30
# ChenZhiPeng_30cm_Mate30
# ChenZhiPeng_站着_mate30

# %%
# trainSet = testDataset(True)

# %%
model = tf.keras.models.load_model("checkpoint/model_2way.h5")

# %%
dir_list = os.listdir(r"Set2/test/")
files=[]
for dir in dir_list:
    t=dir.split("_")
    if(len(t)>2):
        t1=t[0]
        t2='_'.join(t[1:])
    else:
        t1=t[0]
        t2=t[1]
    files.append([t1,t2])

# %%
for file in files:
  number = 200
  acc = {}
  shots=15
  all_count = {}  #保存各个类被抽取出的总次数
  label_dic = {}  #保存各个类被抽取出来后预测正确的次数，与上面的总次数相除暂定为预测的准确度
  for i in range(number):
    testing = []
    train_set, test_images, test_labels, keys, test_set = testSet.get_mini_dataset(
          eval_batch_size, eval_iters, shots, classes, name=file[0], situation=file[1], split=True, test=True
      )
    # print(test_set)
    for l in keys:
      if l not in label_dic:
        label_dic[l]=0
      if l not in all_count:
        all_count[l]=0
    old_vars1 = model.get_weights()
    # train
    for images, labels in train_set:
      # print(labels)
      with tf.GradientTape() as tape:
          preds = model(images)
          loss = keras.losses.sparse_categorical_crossentropy(labels, preds)
      # print(loss)
      # print("labels:{}, preds:{}".format(labels,preds))
      grads = tape.gradient(loss, model.trainable_weights)
      optimizer.apply_gradients(zip(grads, model.trainable_weights))
    test_preds = model.predict(test_images)
    test_preds = tf.argmax(test_preds).numpy()
    # if(i%50==0):
    #   print(i)
    print(i)
    # print("labels:{}, preds:{}".format(test_labels,test_preds))
    # test
    for images, labels in test_set:
        old_vars2 = model.get_weights()
        for label in labels:
          # print(label.numpy())
          all_count[keys[label.numpy().astype(int)]]+=1 
        preds = model.predict(images)
        preds = tf.argmax(preds).numpy()
        print("labels:{}, preds:{}".format(labels,preds))
        flags = (labels==preds)
        num_correct = flags.numpy().sum()
        testing.append(num_correct/classes)
        for idx, flag in enumerate(flags):
          if flag:
            label_dic[keys[idx]]+=1
        model.set_weights(old_vars2)
    model.set_weights(old_vars1)
  result = {}
  for key in label_dic.keys():
    result[key] = (label_dic[key]/all_count[key])*100
    print("label:{},  抽取出来的总次数:{},  其中预测正确的次数:{},  acc:{:.2f}%".format(key,all_count[key],label_dic[key],(label_dic[key]/all_count[key])*100))
  with open(r"Set2/result_{}.txt".format(file[0]),"a") as f:
    f.write("{}:{}\n".format(file[1],result[file[0]]))
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# label:WZY,  抽取出来的总次数:325,  其中预测正确的次数:316,  acc:97.23%
# label:XZQ,  抽取出来的总次数:290,  其中预测正确的次数:288,  acc:99.31%
# label:LengChao,  抽取出来的总次数:300,  其中预测正确的次数:291,  acc:97.00%
# label:MengZiYun,  抽取出来的总次数:240,  其中预测正确的次数:204,  acc:85.00%
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'WZY']
# 0
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'QinDang']
# 1
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'LengChao']
# 2
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'XZQ']
# 3
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'QinDang']
# 4
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'XZQ']
# 5
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 6
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'WZY']
# 7
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'WZY']
# 8
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 9
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 10
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_25cm_Mate30
# keys:['ChenZhiPeng', 'MengZiYun']
# 11
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# keys:['QinDang', 0]
# keys:['QinDang', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 12
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'LengChao']
# 13
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'WZY']
# 14
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'XueMeng']
# 15
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 16
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'WZY']
# 17
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'XZQ']
# 18
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'LengChao']
# 19
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 20
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'LengChao']
# 21
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_25cm_Mate30
# keys:['ChenZhiPeng', 'QinDang']
# 22
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'QinDang']
# 23
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'QinDang']
# 24
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'XZQ']
# 25
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'WZY']
# 26
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'XZQ']
# 27
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'MengZiYun']
# 28
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'WZY']
# 29
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'LengChao']
# 30
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'XueMeng']
# 31
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 32
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_25cm_Mate30
# keys:['ChenZhiPeng', 'MengZiYun']
# 33
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# keys:['LengChao', 0]
# keys:['LengChao', 'XueMeng']
# 34
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'LengChao']
# 35
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'WZY']
# 36
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 37
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'MengZiYun']
# 38
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 39
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_25cm_Mate30
# keys:['ChenZhiPeng', 'XueMeng']
# 40
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'XZQ']
# 41
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'MengZiYun']
# 42
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'WZY']
# 43
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'WZY']
# 44
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'MengZiYun']
# 45
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_25cm_Mate30
# keys:['ChenZhiPeng', 'XueMeng']
# 46
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_25cm_Mate30
# keys:['ChenZhiPeng', 'WZY']
# 47
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'WZY']
# 48
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 49
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'QinDang']
# 50
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'XZQ']
# 51
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 52
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'WZY']
# 53
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'MengZiYun']
# 54
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'MengZiYun']
# 55
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'LengChao']
# 56
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'WZY']
# 57
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 58
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'XueMeng']
# 59
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'LengChao']
# 60
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'QinDang']
# 61
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'LengChao']
# 62
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# keys:['XZQ', 0]
# keys:['XZQ', 'MengZiYun']
# 63
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'XueMeng']
# 64
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'XueMeng']
# 65
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'QinDang']
# 66
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'XueMeng']
# 67
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'WZY']
# 68
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 69
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'XueMeng']
# 70
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'QinDang']
# 71
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'XueMeng']
# 72
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'MengZiYun']
# 73
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 74
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'WZY']
# 75
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 76
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'XZQ']
# 77
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'XueMeng']
# 78
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# keys:['LengChao', 0]
# keys:['LengChao', 'XZQ']
# 79
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'QinDang']
# 80
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_25cm_Mate30
# keys:['ChenZhiPeng', 'MengZiYun']
# 81
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'QinDang']
# 82
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'XZQ']
# 83
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'LengChao']
# 84
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'XueMeng']
# 85
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_25cm_Mate30
# keys:['ChenZhiPeng', 'MengZiYun']
# 86
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_25cm_Mate30
# keys:['ChenZhiPeng', 'MengZiYun']
# 87
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# keys:['WZY', 0]
# keys:['WZY', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 88
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'XueMeng']
# 89
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'XZQ']
# 90
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'WZY']
# 91
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'LengChao']
# 92
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'XueMeng']
# 93
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'QinDang']
# 94
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'LengChao']
# 95
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'LengChao']
# 96
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'XZQ']
# 97
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'MengZiYun']
# 98
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'XZQ']
# 99
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'QinDang']
# 100
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'QinDang']
# 101
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'XZQ']
# 102
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'XZQ']
# 103
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'LengChao']
# 104
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'LengChao']
# 105
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'LengChao']
# 106
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'WZY']
# 107
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'MengZiYun']
# 108
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'QinDang']
# 109
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 110
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'WZY']
# 111
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'XueMeng']
# 112
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'XueMeng']
# 113
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'XZQ']
# 114
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'WZY']
# 115
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'XueMeng']
# 116
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'LengChao']
# 117
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'QinDang']
# 118
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'XZQ']
# 119
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 120
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 121
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'WZY']
# 122
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_25cm_Mate30
# keys:['ChenZhiPeng', 'MengZiYun']
# 123
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_25cm_Mate30
# keys:['ChenZhiPeng', 'XueMeng']
# 124
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'XZQ']
# 125
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'XZQ']
# 126
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_25cm_Mate30
# keys:['ChenZhiPeng', 'XZQ']
# 127
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_25cm_Mate30
# keys:['ChenZhiPeng', 'WZY']
# 128
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 129
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 130
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'WZY']
# 131
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_25cm_Mate30
# keys:['ChenZhiPeng', 'XZQ']
# 132
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'LengChao']
# 133
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'MengZiYun']
# 134
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'WZY']
# 135
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'XZQ']
# 136
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'XZQ']
# 137
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 138
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_25cm_Mate30
# keys:['ChenZhiPeng', 'XueMeng']
# 139
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_25cm_Mate30
# keys:['ChenZhiPeng', 'QinDang']
# 140
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'WZY']
# 141
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'QinDang']
# 142
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'LengChao']
# 143
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 144
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'XZQ']
# 145
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 146
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'MengZiYun']
# 147
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 148
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 149
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'MengZiYun']
# 150
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'QinDang']
# 151
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'WZY']
# 152
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_25cm_Mate30
# keys:['ChenZhiPeng', 'WZY']
# 153
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'LengChao']
# 154
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'XZQ']
# 155
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'MengZiYun']
# 156
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'XZQ']
# 157
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'MengZiYun']
# 158
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 159
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'WZY']
# 160
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'MengZiYun']
# 161
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 162
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'XZQ']
# 163
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'MengZiYun']
# 164
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'WZY']
# 165
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'XZQ']
# 166
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'LengChao']
# 167
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'MengZiYun']
# 168
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'WZY']
# 169
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'XZQ']
# 170
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'XZQ']
# 171
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 172
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_25cm_Mate30
# keys:['ChenZhiPeng', 'LengChao']
# 173
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 174
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 175
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'MengZiYun']
# 176
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 177
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'MengZiYun']
# 178
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'XueMeng']
# 179
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'MengZiYun']
# 180
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'LengChao']
# 181
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'QinDang']
# 182
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'LengChao']
# 183
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# keys:['QinDang', 0]
# keys:['QinDang', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 184
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'XueMeng']
# 185
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_25cm_Mate30
# keys:['ChenZhiPeng', 'MengZiYun']
# 186
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_25cm_Mate30
# keys:['ChenZhiPeng', 'XueMeng']
# 187
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'QinDang']
# 188
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 189
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'XZQ']
# 190
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 191
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'WZY']
# 192
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_25cm_Mate30
# keys:['ChenZhiPeng', 'WZY']
# 193
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'XueMeng']
# 194
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'WZY']
# 195
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 196
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 197
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 198
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'ChenZhiPeng']
# ChenZhiPeng_25cm_Mate30
# 199
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# label:MengZiYun,  抽取出来的总次数:300,  其中预测正确的次数:237,  acc:79.00%
# label:WZY,  抽取出来的总次数:260,  其中预测正确的次数:256,  acc:98.46%
# label:XZQ,  抽取出来的总次数:330,  其中预测正确的次数:329,  acc:99.70%
# label:QinDang,  抽取出来的总次数:250,  其中预测正确的次数:250,  acc:100.00%
# label:LengChao,  抽取出来的总次数:270,  其中预测正确的次数:250,  acc:92.59%
# label:XueMeng,  抽取出来的总次数:290,  其中预测正确的次数:285,  acc:98.28%
# label:ChenZhiPeng,  抽取出来的总次数:300,  其中预测正确的次数:257,  acc:85.67%
# keys:['QinDang', 0]
# keys:['QinDang', 'ChenZhiPeng']
# ChenZhiPeng_30cm_Mate30
# 0
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'ChenZhiPeng']
# ChenZhiPeng_30cm_Mate30
# 1
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'XZQ']
# 2
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'XZQ']
# 3
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'QinDang']
# 4
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_30cm_Mate30
# keys:['ChenZhiPeng', 'LengChao']
# 5
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'ChenZhiPeng']
# ChenZhiPeng_30cm_Mate30
# 6
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'ChenZhiPeng']
# ChenZhiPeng_30cm_Mate30
# 7
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_30cm_Mate30
# keys:['ChenZhiPeng', 'MengZiYun']
# 8
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'ChenZhiPeng']
# ChenZhiPeng_30cm_Mate30
# 9
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'QinDang']
# 10
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'XZQ']
# 11
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'MengZiYun']
# 12
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'XZQ']
# 13
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'MengZiYun']
# 14
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'XueMeng']
# 15
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'MengZiYun']
# 16
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'ChenZhiPeng']
# ChenZhiPeng_30cm_Mate30
# 17
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'QinDang']
# 18
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'LengChao']
# 19
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'ChenZhiPeng']
# ChenZhiPeng_30cm_Mate30
# 20
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'WZY']
# 21
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'XueMeng']
# 22
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'XZQ']
# 23
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'LengChao']
# 24
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'QinDang']
# 25
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'WZY']
# 26
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'QinDang']
# 27
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'WZY']
# 28
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'ChenZhiPeng']
# ChenZhiPeng_30cm_Mate30
# 29
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'QinDang']
# 30
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'LengChao']
# 31
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'WZY']
# 32
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_30cm_Mate30
# keys:['ChenZhiPeng', 'QinDang']
# 33
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'XZQ']
# 34
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'XueMeng']
# 35
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'ChenZhiPeng']
# ChenZhiPeng_30cm_Mate30
# 36
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'WZY']
# 37
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_30cm_Mate30
# keys:['ChenZhiPeng', 'MengZiYun']
# 38
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# ...
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'QinDang']
# 122
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'MengZiYun']
# 123
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'XueMeng']
# 124
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'ChenZhiPeng']
# ChenZhiPeng_站着_mate30
# 125
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'WZY']
# 126
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'MengZiYun']
# 127
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'QinDang']
# 128
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'WZY']
# 129
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'XueMeng']
# 130
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'XZQ']
# 131
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'XZQ']
# 132
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'MengZiYun']
# 133
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'XZQ']
# 134
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_站着_mate30
# keys:['ChenZhiPeng', 'XueMeng']
# 135
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_站着_mate30
# keys:['ChenZhiPeng', 'LengChao']
# 136
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'QinDang']
# 137
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'QinDang']
# 138
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'XZQ']
# 139
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'ChenZhiPeng']
# ChenZhiPeng_站着_mate30
# 140
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'ChenZhiPeng']
# ChenZhiPeng_站着_mate30
# 141
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'MengZiYun']
# 142
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_站着_mate30
# keys:['ChenZhiPeng', 'QinDang']
# 143
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'XueMeng']
# 144
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'XZQ']
# 145
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_站着_mate30
# keys:['ChenZhiPeng', 'WZY']
# 146
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'ChenZhiPeng']
# ChenZhiPeng_站着_mate30
# 147
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'XueMeng']
# 148
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'LengChao']
# 149
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'LengChao']
# 150
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'QinDang']
# 151
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'MengZiYun']
# 152
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'XueMeng']
# 153
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'LengChao']
# 154
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_站着_mate30
# keys:['ChenZhiPeng', 'WZY']
# 155
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'QinDang']
# 156
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'XZQ']
# 157
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'LengChao']
# 158
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'XZQ']
# 159
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_站着_mate30
# keys:['ChenZhiPeng', 'WZY']
# 160
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'MengZiYun']
# 161
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'ChenZhiPeng']
# ChenZhiPeng_站着_mate30
# 162
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'MengZiYun']
# 163
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'LengChao']
# 164
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'XZQ']
# 165
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'MengZiYun']
# 166
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'WZY']
# 167
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'ChenZhiPeng']
# ChenZhiPeng_站着_mate30
# 168
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'XueMeng']
# 169
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'XZQ']
# 170
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'QinDang']
# 171
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'WZY']
# 172
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'XZQ']
# 173
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'ChenZhiPeng']
# ChenZhiPeng_站着_mate30
# 174
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'MengZiYun']
# 175
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_站着_mate30
# keys:['ChenZhiPeng', 'QinDang']
# 176
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'ChenZhiPeng']
# ChenZhiPeng_站着_mate30
# 177
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'ChenZhiPeng']
# ChenZhiPeng_站着_mate30
# 178
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_站着_mate30
# keys:['ChenZhiPeng', 'XueMeng']
# 179
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['QinDang', 0]
# keys:['QinDang', 'MengZiYun']
# 180
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_站着_mate30
# keys:['ChenZhiPeng', 'LengChao']
# 181
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_站着_mate30
# keys:['ChenZhiPeng', 'WZY']
# 182
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'LengChao']
# 183
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'LengChao']
# 184
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['WZY', 0]
# keys:['WZY', 'MengZiYun']
# 185
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_站着_mate30
# keys:['ChenZhiPeng', 'MengZiYun']
# 186
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# keys:['XZQ', 0]
# keys:['XZQ', 'XueMeng']
# 187
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'XZQ']
# 188
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'QinDang']
# 189
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['ChenZhiPeng', 0]
# ChenZhiPeng_站着_mate30
# keys:['ChenZhiPeng', 'XZQ']
# 190
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'WZY']
# 191
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'WZY']
# 192
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['XZQ', 0]
# keys:['XZQ', 'QinDang']
# 193
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'XueMeng']
# 194
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'WZY']
# 195
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'ChenZhiPeng']
# ChenZhiPeng_站着_mate30
# 196
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# labels:[0. 1.], preds:[1 0]
# keys:['MengZiYun', 0]
# keys:['MengZiYun', 'XueMeng']
# 197
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[1 0]
# keys:['XueMeng', 0]
# keys:['XueMeng', 'ChenZhiPeng']
# ChenZhiPeng_站着_mate30
# 198
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# keys:['LengChao', 0]
# keys:['LengChao', 'XZQ']
# 199
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# labels:[0. 1.], preds:[0 1]
# label:LengChao,  抽取出来的总次数:315,  其中预测正确的次数:308,  acc:97.78%
# label:ChenZhiPeng,  抽取出来的总次数:285,  其中预测正确的次数:239,  acc:83.86%
# label:WZY,  抽取出来的总次数:270,  其中预测正确的次数:264,  acc:97.78%
# label:MengZiYun,  抽取出来的总次数:295,  其中预测正确的次数:242,  acc:82.03%
# label:XZQ,  抽取出来的总次数:275,  其中预测正确的次数:273,  acc:99.27%
# label:XueMeng,  抽取出来的总次数:285,  其中预测正确的次数:275,  acc:96.49%
# label:QinDang,  抽取出来的总次数:275,  其中预测正确的次数:275,  acc:100.00%

# %%
import os
dir = os.listdir('./Set2/test/')
for i in dir:
  print(i)
# Out:
# ChenZhiPeng_走动_mate30
# ChenZhiPeng_平躺床_mate30
# ChenZhiPeng_5cm_Mate30
# ChenZhiPeng_仰躺_mate30
# ChenZhiPeng_OKGoogle_mate30
# ChenZhiPeng_10cm_Mate30
# ChenZhiPeng_20cm_Mate30
# ChenZhiPeng_25cm_Mate30
# ChenZhiPeng_30cm_Mate30
# ChenZhiPeng_站着_mate30

# %%
import os
import time
dir = './split/test/ChenZhiPeng'
flag = os.path.exists(dir)
print("开始")
while flag!=True:
  print("一次尝试")
  flag = os.path.exists(dir)
  time.sleep(2)
print("已修改")
# Out:
# 开始
# 已修改
